# %%
import pandas as pd
import seaborn as sns
import numpy as np

df = pd.read_csv('../../datasets/BMW sales data (2010-2024).csv', index_col='Year')
df.head()
# Out:
#          Model         Region  Color Fuel_Type Transmission  Engine_Size_L  \
# Year
# 2016  5 Series           Asia    Red    Petrol       Manual            3.5
# 2013        i8  North America    Red    Hybrid    Automatic            1.6
# 2022  5 Series  North America   Blue    Petrol    Automatic            4.5
# 2024        X3    Middle East   Blue    Petrol    Automatic            1.7
# 2020  7 Series  South America  Black    Diesel       Manual            2.1
#
#       Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# Year
# 2016      151748      98740          8300                 High
# 2013      121671      79219          3428                  Low
# 2022       10991     113265          6994                  Low
# 2024       27255      60971          4047                  Low
# 2020      122131      49898          3080                  Low

# %%
sns.lineplot(data=df.groupby(by=['Model','Year']).Price_USD.mean().reset_index(name='Price_Mean'), x='Year', y='Price_Mean', hue='Model')
# Out:
# <Axes: xlabel='Model', ylabel='Price_Mean'>

# %%
df[['Model', 'Price_USD']]
# Out:
#          Model  Price_USD
# Year
# 2016  5 Series      98740
# 2013        i8      79219
# 2022  5 Series     113265
# 2024        X3      60971
# 2020  7 Series      49898
# ...        ...        ...
# 2014        i3      42932
# 2023        i3      48714
# 2010  5 Series      46126
# 2020        i3      58566
# 2020        X1      77492
#
# [50000 rows x 2 columns]

# %%
df.groupby(by=['Model','Year']).Price_USD.mean().reset_index(name='Price_Mean')
# Out:
#         Model  Year    Price_Mean
# 0    3 Series  2010  75495.605678
# 1    3 Series  2011  75476.890785
# 2    3 Series  2012  75193.351254
# 3    3 Series  2013  73122.545151
# 4    3 Series  2014  75244.906832
# ..        ...   ...           ...
# 160        i8  2020  75819.689895
# 161        i8  2021  74907.394558
# 162        i8  2022  73369.700000
# 163        i8  2023  76119.940789
# 164        i8  2024  76449.084416
#
# [165 rows x 3 columns]

# %%
np.array(df.groupby(by=['Model','Year']).Price_USD.mean())
# Out:
# array([75495.60567823, 75476.89078498, 75193.35125448, 73122.5451505 ,
#        75244.9068323 , 75946.5968254 , 75357.56269113, 75129.50814332,
#        74691.43987342, 76310.78350515, 77888.27457627, 75743.00619195,
#        74994.99681529, 76426.51839465, 76603.2885906 , 73764.4916388 ,
#        76685.03278689, 75531.54849498, 74612.93243243, 73848.14189189,
#        74823.15243902, 77096.17784257, 75338.82352941, 74825.08928571,
#        74325.13333333, 76141.33550489, 75243.99322034, 75215.75247525,
#        76061.19520548, 75527.85365854, 76126.29032258, 74527.9184953 ,
#        75957.77627119, 76760.82847896, 77823.753125  , 74633.15644172,
#        77351.56187291, 75140.41690962, 74889.85324232, 77551.14285714,
#        73016.31147541, 74132.08333333, 74480.63939394, 76240.2394822 ,
#        75333.67987805, 75610.1369863 , 76497.96703297, 74506.8975265 ,
#        75684.54295533, 74654.85064935, 72099.02922078, 75222.39322034,
# ...
