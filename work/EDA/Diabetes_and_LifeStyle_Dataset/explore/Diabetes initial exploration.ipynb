# %%
import pandas as pd
from sklearn.model_selection import train_test_split

diabetes_data_set = pd.read_csv('../../../datasets/Diabetes_and_LifeStyle_Dataset.csv')
diabetes_data_set
# Out:
#        Age  gender ethnicity education_level  income_level employment_status  \
# 0       58    Male     Asian      Highschool  Lower-Middle          Employed
# 1       52  Female     White      Highschool        Middle          Employed
# 2       60    Male  Hispanic      Highschool        Middle        Unemployed
# 3       74  Female     Black      Highschool           Low           Retired
# 4       46    Male     White        Graduate        Middle           Retired
# ...    ...     ...       ...             ...           ...               ...
# 97292   46    Male     Other        Graduate  Upper-Middle        Unemployed
# 97293   41  Female     White        Graduate        Middle          Employed
# 97294   57  Female     Black       No formal  Upper-Middle          Employed
# 97295   47  Female     Black      Highschool  Lower-Middle           Retired
# 97296   52  Female     White    Postgraduate        Middle          Employed
#
#       smoking_status  alcohol_consumption_per_week  \
# 0              Never                             0
# 1             Former                             1
# 2              Never                             1
# 3              Never                             0
# 4              Never                             1
# ...              ...                           ...
# 97292         Former                             1
# 97293          Never                             3
# 97294         Former                             4
# 97295          Never                             3
# 97296          Never                             1
#
#        physical_activity_minutes_per_week  diet_score  ...  hdl_cholesterol  \
# 0                                     215         5.7  ...               41
# 1                                     143         6.7  ...               55
# 2                                      57         6.4  ...               66
# 3                                      49         3.4  ...               50
# 4                                     109         7.2  ...               52
# ...                                   ...         ...  ...              ...
# 97292                                 136         8.3  ...               45
# 97293                                  76         8.8  ...               55
# 97294                                 121         9.9  ...               50
# 97295                                  52         5.9  ...               68
# 97296                                 248         2.7  ...               31
#
#        ldl_cholesterol  triglycerides  glucose_fasting  glucose_postprandial  \
# 0                  160            145              136                   236
# 1                   50             30               93                   150
# 2                   99             36              118                   195
# 3                   79            140              139                   253
# 4                  125            160              137                   184
# ...                ...            ...              ...                   ...
# 97292              150            116              113                   109
# 97293              123            146               96                   146
# 97294              111            184               93                   132
# 97295               91            116              106                   117
# 97296              183             87               91                   142
#
#        insulin_level  hba1c  diabetes_risk_score  diabetes_stage  \
# 0               6.36   8.18                 29.6          Type 2
# 1               2.00   5.63                 23.0     No Diabetes
# 2               5.07   7.51                 44.7          Type 2
# 3               5.28   9.03                 38.2          Type 2
# 4              12.74   7.20                 23.5          Type 2
# ...              ...    ...                  ...             ...
# 97292          14.58   5.55                 26.0    Pre-Diabetes
# 97293           9.02   5.97                 24.4    Pre-Diabetes
# 97294           2.57   5.21                 27.6     No Diabetes
# 97295           9.81   5.53                 26.4    Pre-Diabetes
# 97296          15.93   5.73                 27.9    Pre-Diabetes
#
#        diagnosed_diabetes
# 0                       1
# 1                       0
# 2                       1
# 3                       1
# 4                       1
# ...                   ...
# 97292                   0
# 97293                   0
# 97294                   0
# 97295                   0
# 97296                   0
#
# [97297 rows x 31 columns]

# %%
y = diabetes_data_set['diagnosed_diabetes']
X = diabetes_data_set.copy()
X.drop(columns = ['diagnosed_diabetes'], inplace=True)
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.4,
    random_state=42
)
X_test, X_val, y_test, y_val = train_test_split(
    X_test,
    y_test,
    train_size=0.5,
    random_state=42
)
diabetes_data_set_train = pd.concat([X_train, y_train], axis=1)
diabetes_data_set_train
# Out:
#        Age  gender ethnicity education_level  income_level employment_status  \
# 1114    52    Male     White        Graduate        Middle          Employed
# 36685   66  Female     White        Graduate  Lower-Middle           Retired
# 35104   25    Male     Black      Highschool           Low          Employed
# 4905    44  Female     White      Highschool        Middle          Employed
# 20393   51    Male     White    Postgraduate        Middle          Employed
# ...    ...     ...       ...             ...           ...               ...
# 6265    59    Male     White       No formal          High          Employed
# 54886   43    Male     Black        Graduate  Lower-Middle          Employed
# 76820   65    Male     White    Postgraduate        Middle          Employed
# 860     69  Female     Asian      Highschool        Middle          Employed
# 15795   68    Male     White        Graduate  Lower-Middle          Employed
#
#       smoking_status  alcohol_consumption_per_week  \
# 1114         Current                             4
# 36685          Never                             0
# 35104          Never                             3
# 4905           Never                             2
# 20393          Never                             3
# ...              ...                           ...
# 6265         Current                             4
# 54886         Former                             4
# 76820          Never                             6
# 860           Former                             1
# 15795        Current                             0
#
#        physical_activity_minutes_per_week  diet_score  ...  hdl_cholesterol  \
# 1114                                  117         7.4  ...               53
# 36685                                 114         6.6  ...               59
# 35104                                   4         6.2  ...               56
# 4905                                   44         5.5  ...               55
# 20393                                 182         4.1  ...               57
# ...                                   ...         ...  ...              ...
# 6265                                  216         6.6  ...               42
# 54886                                 146         9.2  ...               46
# 76820                                  40         8.7  ...               50
# 860                                   100         6.8  ...               51
# 15795                                  65         2.7  ...               47
#
#        ldl_cholesterol  triglycerides  glucose_fasting  glucose_postprandial  \
# 1114               127             30              105                   157
# 36685               81            126              100                   165
# 35104              100            133              122                   142
# 4905                54             94              128                   168
# 20393               80            112              104                   137
# ...                ...            ...              ...                   ...
# 6265               151            126              115                   183
# 54886              120             54              103                   187
# 76820              175            165              111                   140
# 860                113            129              142                   183
# 15795              111            122              114                   178
#
#        insulin_level  hba1c  diabetes_risk_score  diabetes_stage  \
# 1114           12.15   6.58                 24.4          Type 2
# 36685           6.94   6.68                 28.7          Type 2
# 35104          14.93   6.39                 24.0    Pre-Diabetes
# 4905           15.65   7.21                 45.0          Type 2
# 20393           6.19   6.37                 23.8    Pre-Diabetes
# ...              ...    ...                  ...             ...
# 6265           13.89   7.50                 28.5          Type 2
# 54886           2.00   7.14                 20.2          Type 2
# 76820          12.16   5.99                 30.8          Type 2
# 860             2.00   7.08                 29.2          Type 2
# 15795           6.18   6.37                 36.1    Pre-Diabetes
#
#        diagnosed_diabetes
# 1114                    1
# 36685                   1
# 35104                   0
# 4905                    1
# 20393                   0
# ...                   ...
# 6265                    1
# 54886                   1
# 76820                   1
# 860                     1
# 15795                   0
#
# [58378 rows x 31 columns]

# %%
print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
# Out:
# (58378, 30)
# (19459, 30)
# (19460, 30)

# %%
diabetes_data_set_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 58378 entries, 1114 to 15795
# Data columns (total 31 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Age                                 58378 non-null  int64
#  1   gender                              58378 non-null  object
#  2   ethnicity                           58378 non-null  object
#  3   education_level                     58378 non-null  object
#  4   income_level                        58378 non-null  object
#  5   employment_status                   58378 non-null  object
#  6   smoking_status                      58378 non-null  object
#  7   alcohol_consumption_per_week        58378 non-null  int64
#  8   physical_activity_minutes_per_week  58378 non-null  int64
#  9   diet_score                          58378 non-null  float64
#  10  sleep_hours_per_day                 58378 non-null  float64
#  11  screen_time_hours_per_day           58378 non-null  float64
#  12  family_history_diabetes             58378 non-null  int64
#  13  hypertension_history                58378 non-null  int64
#  14  cardiovascular_history              58378 non-null  int64
#  15  bmi                                 58378 non-null  float64
#  16  waist_to_hip_ratio                  58378 non-null  float64
#  17  systolic_bp                         58378 non-null  int64
#  18  diastolic_bp                        58378 non-null  int64
#  19  heart_rate                          58378 non-null  int64
#  20  cholesterol_total                   58378 non-null  int64
#  21  hdl_cholesterol                     58378 non-null  int64
#  22  ldl_cholesterol                     58378 non-null  int64
#  23  triglycerides                       58378 non-null  int64
#  24  glucose_fasting                     58378 non-null  int64
#  25  glucose_postprandial                58378 non-null  int64
#  26  insulin_level                       58378 non-null  float64
#  27  hba1c                               58378 non-null  float64
#  28  diabetes_risk_score                 58378 non-null  float64
#  29  diabetes_stage                      58378 non-null  object
#  30  diagnosed_diabetes                  58378 non-null  int64
# dtypes: float64(8), int64(16), object(7)
# memory usage: 14.3+ MB

# %%
diabetes_data_set_train.describe()
# Out:
#                 Age  alcohol_consumption_per_week  \
# count  58378.000000                  58378.000000
# mean      50.264175                      2.004625
# std       15.552249                      1.420672
# min       19.000000                      0.000000
# 25%       38.000000                      1.000000
# 50%       51.000000                      2.000000
# 75%       61.000000                      3.000000
# max       90.000000                     10.000000
#
#        physical_activity_minutes_per_week    diet_score  sleep_hours_per_day  \
# count                        58378.000000  58378.000000         58378.000000
# mean                           118.741290      5.991197             6.999282
# std                             84.577371      1.785515             1.091744
# min                              0.000000      0.000000             3.000000
# 25%                             56.000000      4.800000             6.300000
# 50%                             99.000000      6.000000             7.000000
# 75%                            160.000000      7.200000             7.700000
# max                            833.000000     10.000000            10.000000
#
#        screen_time_hours_per_day  family_history_diabetes  \
# count               58378.000000             58378.000000
# mean                    5.989648                 0.220220
# std                     2.468475                 0.414398
# min                     0.500000                 0.000000
# 25%                     4.300000                 0.000000
# 50%                     6.000000                 0.000000
# 75%                     7.700000                 0.000000
# max                    16.500000                 1.000000
#
#        hypertension_history  cardiovascular_history           bmi  ...  \
# count          58378.000000            58378.000000  58378.000000  ...
# mean               0.251430                0.079139     25.621049  ...
# std                0.433839                0.269959      3.579790  ...
# min                0.000000                0.000000     15.000000  ...
# 25%                0.000000                0.000000     23.200000  ...
# 50%                0.000000                0.000000     25.600000  ...
# 75%                1.000000                0.000000     28.000000  ...
# max                1.000000                1.000000     39.200000  ...
#
#        cholesterol_total  hdl_cholesterol  ldl_cholesterol  triglycerides  \
# count       58378.000000     58378.000000     58378.000000   58378.000000
# mean          185.998201        54.034568       103.037840     121.571722
# std            32.001383        10.272864        33.340917      43.330990
# min           100.000000        20.000000        50.000000      30.000000
# 25%           164.000000        47.000000        78.000000      92.000000
# 50%           186.000000        54.000000       102.000000     121.000000
# 75%           208.000000        61.000000       126.000000     151.000000
# max           318.000000        98.000000       247.000000     298.000000
#
#        glucose_fasting  glucose_postprandial  insulin_level         hba1c  \
# count     58378.000000          58378.000000   58378.000000  58378.000000
# mean        111.140190            160.053496       9.057076      6.521258
# std          13.596805             30.927799       4.948079      0.814883
# min          60.000000             70.000000       2.000000      4.000000
# 25%         102.000000            139.000000       5.090000      5.970000
# 50%         111.000000            160.000000       8.800000      6.520000
# 75%         120.000000            181.000000      12.440000      7.070000
# max         172.000000            281.000000      30.760000      9.700000
#
#        diabetes_risk_score  diagnosed_diabetes
# count         58378.000000        58378.000000
# mean             30.263044            0.599746
# std               9.084864            0.489954
# min               2.700000            0.000000
# 25%              23.800000            0.000000
# 50%              29.000000            1.000000
# 75%              35.700000            1.000000
# max              66.100000            1.000000
#
# [8 rows x 24 columns]

# %%
numeric_cols = [col for col in diabetes_data_set_train.columns 
 if diabetes_data_set_train[col].dtype in ['int64', 'float64']]
numeric_cols
# Out:
# ['Age',
#  'alcohol_consumption_per_week',
#  'physical_activity_minutes_per_week',
#  'diet_score',
#  'sleep_hours_per_day',
#  'screen_time_hours_per_day',
#  'family_history_diabetes',
#  'hypertension_history',
#  'cardiovascular_history',
#  'bmi',
#  'waist_to_hip_ratio',
#  'systolic_bp',
#  'diastolic_bp',
#  'heart_rate',
#  'cholesterol_total',
#  'hdl_cholesterol',
#  'ldl_cholesterol',
#  'triglycerides',
#  'glucose_fasting',
#  'glucose_postprandial',
#  'insulin_level',
#  'hba1c',
#  'diabetes_risk_score',
#  'diagnosed_diabetes']

# %%
numeric_high_std_cols = [col for col in diabetes_data_set_train.columns
                        if diabetes_data_set_train[col].dtype in ['int64', 'float64'] 
                         and diabetes_data_set_train[col].std() > 1]
numeric_high_std_cols
# Out:
# ['Age',
#  'alcohol_consumption_per_week',
#  'physical_activity_minutes_per_week',
#  'diet_score',
#  'sleep_hours_per_day',
#  'screen_time_hours_per_day',
#  'bmi',
#  'systolic_bp',
#  'diastolic_bp',
#  'heart_rate',
#  'cholesterol_total',
#  'hdl_cholesterol',
#  'ldl_cholesterol',
#  'triglycerides',
#  'glucose_fasting',
#  'glucose_postprandial',
#  'insulin_level',
#  'diabetes_risk_score']

# %%
diabetes_data_set[numeric_high_std_cols].describe()
print(len(numeric_high_std_cols))
# Out:
# 18

# %%
print(len(numeric_cols))
# Out:
# 24

# %%
diabetes_data_set_train[[col for col in diabetes_data_set_train.columns 
if diabetes_data_set_train[col].dtype == 'object']].
# Out:
# gender  ethnicity  education_level  income_level  employment_status  smoking_status  diabetes_stage
# Female  White      Highschool       Middle        Employed           Never           Type 2            445
# Male    White      Highschool       Middle        Employed           Never           Type 2            433
# Female  White      Graduate         Middle        Employed           Never           Type 2            345
# Male    White      Graduate         Middle        Employed           Never           Type 2            339
#                    Highschool       Lower-Middle  Employed           Never           Type 2            338
#                                                                                                       ...
# Female  Other      Highschool       Lower-Middle  Student            Current         Type 2              1
# Male    Other      Postgraduate     Middle        Employed           Former          No Diabetes         1
# Female  Black      No formal        Low           Retired            Current         Type 2              1
# Male    Black      Graduate         Upper-Middle  Student            Former          Type 2              1
# Other   White      Postgraduate     Upper-Middle  Unemployed         Never           Type 2              1
# Name: count, Length: 5781, dtype: int64
