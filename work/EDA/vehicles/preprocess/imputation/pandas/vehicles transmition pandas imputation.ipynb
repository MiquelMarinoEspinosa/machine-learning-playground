# %%
import pandas as pd
from sklearn.model_selection import train_test_split

vehicles_data_set = pd.read_csv('/home/jovyan/work/datasets/vehicles_cleaned.csv')
vehicles_data_set
# Out:
#         price    year manufacturer    fuel  odometer title_status  \
# 0        6000     NaN          NaN     NaN       NaN          NaN
# 1       11900     NaN          NaN     NaN       NaN          NaN
# 2       21000     NaN          NaN     NaN       NaN          NaN
# 3        1500     NaN          NaN     NaN       NaN          NaN
# 4        4900     NaN          NaN     NaN       NaN          NaN
# ...       ...     ...          ...     ...       ...          ...
# 426875  23590  2019.0       nissan     gas   32226.0        clean
# 426876  30590  2020.0        volvo     gas   12029.0        clean
# 426877  34990  2020.0     cadillac  diesel    4174.0        clean
# 426878  28990  2018.0        lexus     gas   30112.0        clean
# 426879  30590  2019.0          bmw     gas   22716.0        clean
#
#        transmission       type state
# 0               NaN        NaN    az
# 1               NaN        NaN    ar
# 2               NaN        NaN    fl
# ...

# %%
X = vehicles_data_set.copy()
y = vehicles_data_set['price']

X.drop(columns=['price'], inplace=True)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    train_size=0.6,
    random_state=42
)

X_test, X_val, y_test, y_val = train_test_split(
    X_test,
    y_test,
    train_size=0.5,
    random_state=42
)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((256128, 8), (256128,), (85376, 8), (85376,), (85376, 8), (85376,))

# %%
X_train['transmission'].unique()
# Out:
# array(['automatic', 'other', 'manual', nan], dtype=object)

# %%
index_rows_transmission_null = X_train[X_train['transmission'].isnull()].index.to_list()

X_train_transmission_ffill_imputed = X_train.copy()

print(
    X_train_transmission_ffill_imputed.isnull().any()
)

X_train_transmission_ffill_imputed.ffill(inplace=True)

print(
    X_train_transmission_ffill_imputed.isnull().any()
)
# Out:
# [368797,
#  232517,
#  105247,
#  237353,
#  127979,
#  330404,
#  111982,
#  117291,
#  422810,
#  304940,
#  167765,
#  319437,
#  197408,
#  254026,
#  234493,
#  98708,
#  176029,
#  238430,
#  44771,
#  389528,
#  5384,
#  330939,
#  130003,
#  256334,
#  360685,
#  266670,
#  57444,
#  190205,
#  254014,
#  401908,
#  370411,
#  241987,
#  8792,
#  286352,
#  168711,
#  42512,
#  234739,
#  400798,
#  368865,
#  123992,
#  229852,
#  6029,
#  255921,
#  128556,
#  100049,
#  330064,
#  255080,
#  167502,
#  118619,
#  30882,
#  245288,
#  116595,
#  81652,
#  45910,
#  127832,
#  236667,
#  58609,
#  189235,
#  233441,
#  257658,
#  238035,
#  8384,
#  169118,
#  401916,
#  235885,
#  116099,
#  33304,
#  130239,
#  128353,
#  389971,
#  320119,
#  335292,
#  51640,
#  329512,
#  411939,
#  361005,
#  362569,
#  283171,
#  307075,
#  128788,
#  389521,
#  77891,
#  132936,
#  8800,
#  8803,
#  105553,
#  401911,
#  202741,
#  250009,
#  254069,
#  232308,
#  115406,
#  7169,
# ...
