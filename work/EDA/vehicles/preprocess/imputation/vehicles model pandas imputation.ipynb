# %%
import pandas as pd
from sklearn.model_selection import train_test_split

vehicles_dataset = pd.read_csv('/home/jovyan/work/datasets/vehicles_cleaned.csv')
vehicles_dataset
# Out:
#                         region  price    year manufacturer  \
# 0                     prescott   6000     NaN          NaN
# 1                 fayetteville  11900     NaN          NaN
# 2                 florida keys  21000     NaN          NaN
# 3       worcester / central MA   1500     NaN          NaN
# 4                   greensboro   4900     NaN          NaN
# ...                        ...    ...     ...          ...
# 426875                 wyoming  23590  2019.0       nissan
# 426876                 wyoming  30590  2020.0        volvo
# 426877                 wyoming  34990  2020.0     cadillac
# 426878                 wyoming  28990  2018.0        lexus
# 426879                 wyoming  30590  2019.0          bmw
#
#                            model    fuel  odometer title_status transmission  \
# 0                            NaN     NaN       NaN          NaN          NaN
# 1                            NaN     NaN       NaN          NaN          NaN
# 2                            NaN     NaN       NaN          NaN          NaN
# 3                            NaN     NaN       NaN          NaN          NaN
# 4                            NaN     NaN       NaN          NaN          NaN
# ...                          ...     ...       ...          ...          ...
# 426875         maxima s sedan 4d     gas   32226.0        clean        other
# 426876  s60 t5 momentum sedan 4d     gas   12029.0        clean        other
# 426877          xt4 sport suv 4d  diesel    4174.0        clean        other
# 426878           es 350 sedan 4d     gas   30112.0        clean        other
# 426879  4 series 430i gran coupe     gas   22716.0        clean        other
#
#              type state
# 0             NaN    az
# 1             NaN    ar
# 2             NaN    fl
# 3             NaN    ma
# 4             NaN    nc
# ...           ...   ...
# 426875      sedan    wy
# 426876      sedan    wy
# 426877  hatchback    wy
# 426878      sedan    wy
# 426879      coupe    wy
#
# [426880 rows x 11 columns]

# %%
y = vehicles_dataset['price']
X = vehicles_dataset.copy()
X.drop(columns=['price'], inplace=True)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    train_size=0.6,
    random_state=42
)

X_test, X_val, y_test, y_val = train_test_split(
    X_test,
    y_test,
    train_size=0.5,
    random_state=42
)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((256128, 10), (256128,), (85376, 10), (85376,), (85376, 10), (85376,))

# %%
X_train.reset_index(inplace=True, drop=True)
cols_with_null = [col for col in X_train.columns
                 if X_train[col].isnull().any()]
cols_with_null, X_train.columns
# Out:
# (['year',
#   'manufacturer',
#   'model',
#   'fuel',
#   'odometer',
#   'title_status',
#   'transmission',
#   'type'],
#  Index(['region', 'year', 'manufacturer', 'model', 'fuel', 'odometer',
#         'title_status', 'transmission', 'type', 'state'],
#        dtype='object'))

# %%
for col_with_null in cols_with_null:
    print(X_train[col_with_null].value_counts(dropna=False))
# Out:
# year
# 2018.0    21799
# 2017.0    21747
# 2015.0    19016
# 2013.0    18486
# 2016.0    18367
#           ...
# 1920.0        1
# 1913.0        1
# 1918.0        1
# 1901.0        1
# 1943.0        1
# Name: count, Length: 112, dtype: int64
# manufacturer
# ford               42587
# chevrolet          33119
# toyota             20426
# honda              12784
# jeep               11603
# nissan             11405
# ram                10902
# NaN                10624
# gmc                 9975
# bmw                 8756
# dodge               8255
# mercedes-benz       7066
# hyundai             6149
# subaru              5702
# volkswagen          5598
# kia                 5097
# lexus               4911
# audi                4630
# cadillac            4172
# chrysler            3560
# acura               3547
# buick               3290
# mazda               3281
# infiniti            2911
# lincoln             2509
# volvo               2069
# mitsubishi          1968
# mini                1416
# pontiac             1384
# rover               1284
# jaguar              1217
# porsche              848
# mercury              697
# saturn               645
# alfa-romeo           535
# tesla                501
# fiat                 488
# harley-davidson       93
# ferrari               55
# datsun                36
# aston-martin          16
# land rover            15
# morgan                 2
# Name: count, dtype: int64
# model
# f-150                  4676
# NaN                    3186
# silverado 1500         3110
# 1500                   2477
# camry                  1912
#                        ...
# F150 STEPSIDE             1
# accorx                    1
# c7500 7h2                 1
# 3500 crew cab 4wd         1
# f250 super duty stx       1
# Name: count, Length: 22687, dtype: int64
# fuel
# gas         213806
# other        18463
# diesel       18049
# hybrid        3040
# NaN           1758
# electric      1012
# Name: count, dtype: int64
# odometer
# NaN         2673
# 100000.0    1355
# 1.0         1345
# 0.0         1174
# 200000.0    1052
#             ...
# 31654.0        1
# 10227.0        1
# 128305.0       1
# 40777.0        1
# 218666.0       1
# Name: count, Length: 80522, dtype: int64
# title_status
# clean         243152
# NaN             4927
# rebuilt         4285
# salvage         2323
# lien             850
# missing          474
# parts only       117
# Name: count, dtype: int64
# transmission
# automatic    202026
# other         37407
# manual        15170
# NaN            1525
# Name: count, dtype: int64
# type
# NaN            55877
# sedan          52095
# SUV            46492
# pickup         25927
# truck          21042
# other          13253
# coupe          11570
# hatchback       9971
# wagon           6449
# van             5134
# convertible     4701
# mini-van        2921
# offroad          378
# bus              318
# Name: count, dtype: int64

# %%
X_train['model'].unique().tolist()
# Out:
# ['optima',
#  'q45',
#  '4runner sr5 suv',
#  'malibu',
#  'f-150 xlt',
#  'gto',
#  nan,
#  'Junk Cars',
#  'Hudson',
#  'compass',
#  '2003',
#  'fiesta se',
#  'a6 2.0t premium sedan 4d',
#  'transit',
#  'i8',
#  'super duty f-250 srw',
#  'accent gs',
#  'silverado 2500 ltz lifted crew 4wd',
#  'ranger',
#  'grand caravan',
#  'silverado diesels 3500',
#  'silverado 2500hd',
#  'xts',
#  'x6 xdrive35i sport utility',
#  '5 series',
#  'town & country',
#  'sonic',
#  'sequoia',
#  'tlx technology fwd',
#  '4runner limited',
#  'explorer',
#  '1500 classic regular cab',
#  'terrain',
#  'silverado',
#  'es300',
#  '124 spider classica',
#  'cr-v',
#  'sonata',
#  'corvette',
#  'mdx advance pkg sport',
#  'f-350sd',
#  '4 series 440i convertible 2d',
#  'impala ss',
#  'santa fe sesuv 6a',
#  'ANY',
#  'edge limited',
#  'mustang convertible',
#  'altima',
#  'allroad 2.7t',
#  'f-250',
#  'cls-class',
#  'es 350',
#  'jetta 2.5',
#  'prius four touring',
#  'a5 premium coupe 2d',
#  'hs 250 premium',
#  'juke',
#  'optima lx sedan 4d',
#  'e 400',
#  'tahoe',
#  'jetta',
#  '3 series 330i xdrive sedan',
#  'f250',
#  'sierra',
#  '3 series',
#  'lucerne',
#  'forester',
#  'wrangler unlimited rubicon',
#  'ilx',
#  'srx luxury fwd',
#  'taurus',
#  'plymouth voyager',
#  'charger',
#  'corolla',
#  'enclave avenir sport',
#  'armada platinum',
#  'f150',
#  'mariner',
#  'impreza',
#  'pathfinder',
#  'highlander',
#  'mirage g4',
#  'caliber sxt',
#  'q50 3.0t sport sedan 4d',
#  'silverado 1500',
#  'crosstrek 2.0i sport',
#  'trailblazer ls',
#  'kenworth t800',
#  'ls 460 sedan 4d',
#  'mdx sh-awd w/advance pkg',
#  'crv',
#  'corvette stingray',
#  'express cargo van',
#  'camaro ss coupe 2d',
#  'evoque',
#  'cherokee latitude 4x4',
#  'f350 super duty crew cab',
#  'MS250 Mack Midliner',
#  's10',
#  'wrangler',
#  'liberty',
#  'terrain sle sport utility 4d',
#  'captiva sport',
#  'lr4 hse',
#  'sierra 2500hd',
#  'thomas school bus',
#  'transit cargo van',
#  '3 series * - low miles - 1',
#  'versa',
#  'canyon crew cab sle pickup',
#  'canyon',
#  'escape',
#  'challenger',
#  'transit passenger',
#  'sportage lx',
#  'wrangler unlimited sahara',
#  'mkz reserve sedan 4d',
#  'envision premium i sport',
#  '2015 Scion xB Base',
#  'sienna xle',
#  'box truck',
#  'titan xd single cab sv',
#  'e-250',
#  'ITI QX80',
#  '500 lounge',
#  'venza',
#  'fusion',
#  'dakota',
#  'silverado 1500 regular',
#  's-10 sport 283 high performance',
#  'chysler 300 touring l awd',
#  'civic',
#  'cooper hardtop',
#  'beetle 1.8t sel',
#  'corolla le',
#  'avalon trd sedan 4d',
#  'mustang gt coupe 2d',
#  '4 series',
#  'xc70',
#  'a6',
#  'impala',
#  'trailblazer lt 4x4',
#  'transit van',
#  '3500',
#  'wrangler unlimited',
#  'f-150',
#  'mdx sh-awd sport utility',
#  'accent',
#  'prius c three hatchback',
#  'F450 Fontaine',
#  'flex',
#  'tacoma',
#  'cr-z',
#  'Ford, F-150',
#  'elantra sel auto',
#  'srx',
#  'golf alltrack tsi s',
#  'f-250 super duty',
#  'sierra 1500',
#  'cooper countryman',
#  'equinox',
#  'prius',
#  '4 series 430i convertible 2d',
#  'legacy',
#  'tundra sr 4x4',
#  'sable base',
#  'is 250',
#  'ridgeline',
#  'f550 xl',
#  'mustang',
#  's60',
#  'q50',
#  'transit xlt',
#  'gl450 4matic awd',
#  'corsair reserve sport',
#  'crv cr-v 4wd',
#  'renegade upland edition',
#  '5 series 535i xdrive',
#  'oldsmobile alero',
#  'mustang mach-e',
#  'challenger r/t',
#  'traverse',
#  'yukon xl 1500',
#  'f150 xlt',
#  '2500 4x4',
#  'focus',
#  'Scion FR-S',
#  'cruze lt',
#  'f-250 superduty lariat',
#  'juke s',
#  '2500 slt',
#  'Smoker Craft',
#  'leaf sv',
#  'freightliner sprinter 2500',
#  'encore gx select sport',
#  'f-pace',
#  'xc90',
#  'cayenne',
#  'accent se sedan 4d',
#  'transit connect 114.6" xl w/o side or rear door glass',
#  'ioniq hybrid hatchback',
#  'savana passenger',
#  'transit 350',
#  'avalon hybrid limited',
#  'quest',
#  'outback',
#  'civic lx hatchback 4d',
#  'crosstrek 2.0i limited',
#  'hhr',
#  'Spartan Gladiator',
#  'sierra 1500 ext cab 4d slt',
#  'forester 2.0xt touring',
#  'accord',
#  'Other',
#  'escape xlt',
#  'sedona ex',
#  'rogue s',
#  'rogue',
#  'soul s wagon 4d',
#  'blackwood',
#  '300-series',
#  'forte ex',
#  'c-class',
#  'rdx fwd w/advance pkg',
#  'cruze limited',
#  'silverado 2500 ltz',
#  'sierra 1500 crew cab sle',
#  'express 3500',
#  'corolla le 4dr sedan',
#  'e450',
#  'sequoia sr5 sport utility',
#  'camry le',
#  'genesis 3.8 sedan 4d',
#  'frontier',
#  'c230',
#  'optima ex sedan 4d',
#  'f-250 sd',
#  'hardtop 2 door cooper',
#  'cobalt 2dr cpe lt',
#  'corvette grand sport',
#  'is is 350 f sport automatic',
#  'tacoma access cab pickup',
#  'promaster 3500',
#  'ranger supercab xl pickup',
#  'rio5',
#  'soul',
#  'grand caravan passenger',
#  'f250 super duty regular cab',
#  '2500 diesel truck american',
#  'c-hr xle premium sport',
#  '500 pop hatchback 2d',
#  'sentra',
#  'f150 supercrew cab xlt',
#  'x3 xdrive28i sport utility',
#  'benz e320 4matic wagon',
#  'civic hybrid',
#  's',
#  'is250',
#  'prizm lsi',
#  'lx 570',
#  'rav4',
#  'ats',
#  'grand cherokee overland',
#  'ranger supercrew xl pickup',
#  'mustang premium',
#  'Coachmen Freelander',
#  '4runner sr5 sport utility',
#  'excursion',
#  'tundra crewmax pickup 4d',
#  '1500 classic',
#  'versa sedan',
#  'cts-v coupe',
#  'f-350',
#  'promaster 2500 cargo',
#  'nx 300h base',
#  'focus se',
#  's-class',
#  'forte koup sx coupe 2d',
#  'expedition',
#  's5 premium plus coupe 2d',
#  'highlander limited',
#  'ls 460',
#  'benz c300',
#  'santa fe',
#  'edge',
#  'escape se sport utility 4d',
#  'mkt',
#  'q5 premium sport utility 4d',
#  'impala ss 1995',
#  '1500',
#  'sierra 1500 sle',
#  'super duty f-350 drw',
#  'e-450 galvan universal',
#  'avenger sxt',
#  'm30 convertible',
#  'pilot',
#  'trax lt sport utility',
#  'forte lxs sedan 4d',
#  'f-550sd',
#  'g6',
#  'cruze',
#  'cooper s',
#  'Sterling Triaxle',
#  'civic type r touring',
#  'murano',
#  'f-350 utility truck',
#  '4runner sr5',
#  'journey se',
#  'grand cherokee',
#  'glk-class glk 350',
#  'envision premium ii sport',
#  '328i',
#  'grand cherokee trailhawk',
#  'tahoe lt sport utility',
#  'f 350',
#  'dakota 4x4',
#  'expedition xlt sport',
#  'liberty sport',
#  'cruze eco',
#  'beetle convertible',
#  'f350',
#  'paceman cooper s all4',
#  'cherokee sport 4x4',
#  'tacoma prerunner',
#  'dart limited',
#  'cr-v ex-l',
#  'peterbilt 579',
#  '6',
#  'benz s430 4matic',
#  'mazda3',
#  'civic si sedan 4d',
#  'tundra 4wd truck',
#  'pickup 3500',
#  'benz e350',
#  'maxima',
#  '4 series 428i xdrive',
#  'avalon',
#  'rendezvous cx',
#  '3',
#  'scion tc',
#  '3 series 328d xdrive sport',
#  'town and country',
#  'legacy 3.6r',
#  'camry',
#  'rondo',
#  'civic sdn',
#  's70',
#  'pickup',
#  'x5',
#  '750i',
#  'enclave',
#  'BHPH INHOUSE',
#  'renegade',
#  'cruze ltz',
#  'caravan',
#  'elantra',
#  'ridgeline sport pickup 4d',
#  'triumph tr6',
#  'is',
#  'land cruiser',
#  'sentra dr sdn i cvt sr',
#  'savana g 3500',
#  'oldsmobile toronado',
#  'suburban',
#  'cars and suvs',
#  'mkx',
#  'escalade',
#  'patriot sport',
#  'tucson',
#  'solara',
#  'camaro lt coupe 2d',
#  'pilot exl',
#  '911 carrera',
#  'cherokee',
#  'silverado 1500 double',
#  '740li xdrive',
#  'grand cherokee srt8',
#  'a4 premium plus sedan 4d',
#  'odyssey',
#  'yukon xl denali *fr $499 down guaranteed finance',
#  'cj7',
#  'rx-8',
#  'outlander sport es',
#  'blazer 1lt sport',
#  'vmi ♿',
#  'v60 cross country',
#  'elantra se',
#  'traverse lt',
#  'yukon',
#  'rlx sedan 4d',
#  'acadia',
#  'Scion iM Hatchback 4D',
#  'envoy denali',
#  'silverado z-71 4x4',
#  'transit 150',
#  'brz limited coupe 2d',
#  'tl',
#  'allroad',
#  'e-class',
#  'taurus sel',
#  'civic lx',
#  'xt6',
#  'tsx sedan',
#  'wrangler sport suv 2d',
#  'f150 xlt 4x4 1/2 ton gas',
#  'KENWORTH T880',
#  'journey r/t',
#  'xc40 t5 r-design sport',
#  'f150 stx 4wd f-150 4x4',
#  'wrx sti',
#  'altima 2.5 sl',
#  'corolla s',
#  'avalanche ltz',
#  'camaro',
#  'mx-5 miata club',
#  'ilx premium pkg sedan 4d',
#  'silverado 1500 crew',
#  'z3 convertible',
#  'transit cargo',
#  'z4 sdrive28i roadster 2d',
#  'silverado 1500 custom',
#  'c-max hybrid',
#  'mx-5 miata grand touring',
#  'titan crew cab sv pickup',
#  'es',
#  '2500 diesel 4x4 5.9l c',
#  'grand cherokee limited',
#  'xterra',
#  'super duty f-350 srw laria',
#  'gs-f',
#  'gs',
#  'f150 lariat',
#  'rio',
#  'cooper hardtop 2 door',
#  'cr-v lx awd',
#  'a4 2.0t',
#  'escape titanium sport',
#  'equinox lt',
#  'envision',
#  'town country',
#  'rx 350',
#  'cc4500',
#  'grand cherokee laredo',
#  '2914 Mustang V6 coupe',
#  'rsx',
#  'titan platinum reserve',
#  '2500',
#  'acadia denali',
#  '350z',
#  'sorento',
#  'q3',
#  'belair',
#  'captiva sport fleet',
#  'camry le sedan 4d',
#  'fiesta',
#  'benz e320 wagon',
#  'ats premium luxury',
#  'eurovan weekender',
#  'mercedes-amg',
#  '528i',
#  'transit 150 van',
#  'tacoma prerunner sr5 trd',
#  'f150 xlt xtr 4x4 1/2 ton',
#  'avalanche',
#  'mdx sh-awd w/technology',
#  '1500 slt',
#  'ranger xlt',
#  'jetta sportwagen 2.0l',
#  'sl-class sl 550',
#  'supercha',
#  'regal premium ii sedan 4d',
#  'genesis',
#  'sienna xle minivan 4d',
#  'escape sel',
#  'silverado 1500 ld',
#  'xc90 t8 hybrid inscription',
#  'golf',
#  'navigator',
#  'sonata se sedan clean carfax',
#  'volt',
#  'ALL',
#  'challenger r/t shaker',
#  's 90d',
#  'super duty f-250',
#  'yukon slt',
#  'glc 300 sport',
#  'mustang gt deluxe',
#  'sienna',
#  'is 250 crafted line sedan',
#  'rx8',
#  '2013 Freightliner Cascadia',
#  'v70',
#  'civic sport hatchback 4d',
#  'odyssey touring',
#  's90 t5 momentum sedan 4d',
#  'rx 350 sport utility 4d',
#  'q7',
#  'sierra 1500 denali',
#  'rogue sv low miles nice',
#  'f-250 super duty xl',
#  'avalon limited sedan 4d',
#  'es 330',
#  'f250 super duty crew cab xl',
#  '200 limited',
#  'cj-5',
#  'colorado',
#  'challenger srt8 coupe 2d',
#  'titan pro-4x',
#  'f150 xl extended cab',
#  'eos sport convertible',
#  'Miata MX-5 RF',
#  'Freightliner M2 106 Medium Duty',
#  'colorado extended cab',
#  'SPECIAL FINANCE PROGRAM 2020',
#  'silverado 3500 high ct',
#  '300',
#  'sonic lt',
#  'f150 xlt supercrew',
#  'cobalt',
#  'sentra sv',
#  'f350 diesels powerstroke',
#  'k10',
#  'veloster w/black int',
#  'forester 2.5i premium',
#  'challegner sxt',
#  'sierra deisel duramax 2500',
#  '1990 nChevy Cheyenne',
#  'benz ml350',
#  'altima 2.5 s',
#  'c7500 dump truck',
#  '200',
#  'durango',
#  'f150 4x4',
#  'f250 super duty',
#  'wrangler unlimited all new',
#  'a3 sedan',
#  'Janesville',
#  'tacoma v6 4x4double cab',
#  'titan xd crew cab sv',
#  'civic ex sedan 4d',
#  'g g37x sedan 4d',
#  'Freightliner Cascadia',
#  'f-350 sd lariat crew cab 4x',
#  'qx80 luxe sport utility',
#  'ion 2',
#  '5 series 530i xdrive',
#  'super duty f-350 srw',
#  'benz c280 4matic',
#  'f-150 4x4 super crew',
#  'cx-5',
#  'avenger',
#  'acadia slt',
#  '328i xdrive',
#  'a3 premium plus sedan 4d',
#  'tiguan 2.0t sel sport',
#  'Freightliner M2 106',
#  'tundra limited',
#  'silverado 3500 hd',
#  'qx50 sport utility 4d',
#  '1500 crew cab big horn',
#  'cx-9',
#  '1500 st quad cab',
#  'commander',
#  'trailblazer',
#  'escalade premium',
#  'vibe base',
#  'soul base',
#  'e250 3/4 ton cargo van',
#  'xt4',
#  'f-450',
#  'Isuzu Trooper',
#  'x3 xdrive30i sport utility',
#  'sierra 3500 denali duramax',
#  'f350 super duty',
#  'tundra',
#  '1500 express 4x4 gas',
#  'element',
#  'encore essence sport',
#  '4runner limited 1-califonia owner*highway miles*all services done @dealer since new w/records*no rust*moon roof*cooled seats*heated seats*limited*jbl sound system*tow pkg',
#  'f250 4x4 diesel',
#  'sierra diesels duramax 3500',
#  'cts',
#  'town & country touring',
#  'f-250sd',
#  'expedition king ranch 4wd',
#  'm-class',
#  'f450 super duty king ranch',
#  'gx470 4wd',
#  'f350 powerstroke lariat',
#  'impala lt',
#  'frontier crew cab',
#  'Oldsmobile Bravada AWD  Smart Trak',
#  'corolla ce',
#  'cobalt lt',
#  'sierra 1500 regular cab',
#  'xe 25t premium sedan 4d',
#  '500 abarth hatchback 2d',
#  'encore',
#  'lancer 2.0es',
#  'promaster 2500',
#  'xj',
#  'rav4 awd',
#  'x1',
#  'journey r/t sport utility',
#  'wrx',
#  '3500 flatbed',
#  'verano sport touring sedan',
#  'sierra 2500 denali',
#  'tahoe ls 4x4',
#  'mirage g4 rf sedan 4d',
#  'Pontic Firebird',
#  'HINO XJC740 / XFC740',
#  'a4',
#  'a7',
#  'super duty f-450 drw',
#  'lacrosse',
#  's430',
#  'gla 250',
#  'safari awd van',
#  'monte carlo',
#  'acadia sle-1 sport utility',
#  'bus',
#  'explorer xlt',
#  'gx 470',
#  'mark lt',
#  'sierra 2500 hd double cab',
#  'm-class ml 550',
#  'silverado 1500 ltz',
#  'patriot - 4x4 - new tires - recently smogged -',
#  'Mitsbishi MiEV',
#  '2500 hd high country',
#  'durango sxt',
#  'outlander phev gt',
#  'SILVERADO 1500',
#  'qx50 luxe sport utility',
#  'odyssey exl',
#  'international 4400',
#  'f550 4x4',
#  'titan xd',
#  'xt5 luxury sport',
#  'f-150 stx',
#  'cooper hardtop s',
#  'Oldsmobile Aurora',
#  'corvette coupe 6.0l v',
#  'civic ex',
#  'sportage',
#  'f450 super duty',
#  'cherokee latitude 2wd',
#  'insight touring sedan 4d',
#  'x3 xdrive30i',
#  'patriot',
#  '2007 f350 superduty',
#  'continental sedan 4d',
#  'Toyoya RAV4',
#  'traverse ls',
#  'armada sl sport utility',
#  'expedition limited',
#  'silverado 2500 lifted',
#  'gx470',
#  'renegade sport suv 4d',
#  'eclipse',
#  'accord coupe',
#  'sprinter 3500',
#  'acty minitruck',
#  'x3',
#  'explorer xls 4x4',
#  'civic natural gas sedan 4d',
#  'e350 cutaway',
#  'solstice',
#  'm-class 3.5l',
#  'tundra double cab sr5',
#  'f100 pickup',
#  'enclave cxl leather seats',
#  'es 300',
#  'xt6 premium luxury',
#  'sierra 3500hd',
#  'cl type s',
#  'sequoia limited',
#  'fit sport',
#  '2013',
#  'econoline commercial cutaway',
#  'ridgeline rtl',
#  'civic lx 4dr sedan 5a',
#  '300 sdn 300c awd',
#  'express commercial cutaway',
#  'sonic lt auto',
#  '500',
#  'glc-class',
#  'hummer h3 alpha',
#  'deville',
#  'bel air',
#  'continental select sedan',
#  'charger se',
#  'transit passenger wagon',
#  'focus sel',
#  'town car',
#  'pickup 1500',
#  'tundra sr5',
#  'silverado 1500 lt 4x4',
#  'pathfinder 4x4',
#  'highlander hybrid',
#  'impala sdn lt',
#  'f-150 4wd supercrew 145" xlt',
#  'sebring limited',
#  'tow truck',
#  'sierra 2500hd slt',
#  'veracruz limited',
#  'monte carlo ss',
#  'spark activ hatchback',
#  'fj cruiser sport utility',
#  'f150 regular cab xl pickup',
#  'expedition el',
#  'tundra double cab sr',
#  'rav4 xle awd',
#  'international',
#  'econoline',
#  'silverado 3500hd 4x4',
#  'fiesta s',
#  '2500 6.7 cummins diesel 4x4 laramie !!leveled 35s!',
#  '300c',
#  'qx60 pure sport utility',
#  'ecosport',
#  'Suzuki SX4 Crossover',
#  'svx',
#  'crosstour',
#  'transit chassis cab',
#  '-',
#  'c4500',
#  'a4 allroad premium wagon 4d',
#  '3500 mega cab',
#  'g37 coupe',
#  'terrain sle',
#  'q60 3.0t luxe coupe 2d',
#  '7400',
#  'mkx reserve sport',
#  '1500 st',
#  'g37s',
#  '4runner',
#  'suburban lt',
#  'Genesis G80 3.8 Sedan 4D',
#  '2500 suburban',
#  'jetta sportwagen tdi',
#  'aero max l9000',
#  '7 series 740i sedan 4d',
#  'firebird',
#  'edge limited awd',
#  's4',
#  'qx60 3.5 sport utility',
#  'milan',
#  'cooper',
#  'acadia sle-2 sport utility',
#  'camaro ss convertible',
#  'victoria',
#  'x3 xdrive28i',
#  'edsel',
#  'nitro slt',
#  'sierra denali 2500hd',
#  'silverado 3500hd',
#  '1500 4x4 express 4dr quad cab 6.3 ft sb pickup truck clean carfax 2-owner local truck',
#  'pacifica touring plus',
#  'cruze limited ltz',
#  '1500 longhorn limited',
#  'xk',
#  'venza awd',
#  'f350 diesel power stroke',
#  'rogue select',
#  'romeo stelvio ti sport',
#  '4 runner',
#  'Food Trailer',
#  'jetta s',
#  'f250 super duty 4x4',
#  'forte',
#  '7 series 750i xdrive sedan',
#  'equus signature',
#  'f-pace 35t premium sport',
#  'camry se auto (natl)',
#  'xc40',
#  'Isuzu NPR',
#  'frontier se',
#  'transit 250 van low roof',
#  'galant',
#  'u Outback',
#  'benz c320',
#  'tacoma sr5 4x4',
#  '350z convertible',
#  'tacoma access cab',
#  '328',
#  'e-450',
#  'f-150 svt raptor',
#  'malibu 2016',
#  'tiguan',
#  'rogue sl',
#  'tundra texas edition rwd',
#  '325ci',
#  '1500 4x4',
#  'grand caravan gt',
#  'tacoma trd off-road',
#  'terrain slt v6 awd',
#  'xc90 t8 1,300 miles',
#  'golf gti autobahn',
#  'sierra duramax 3500 hd 4x4',
#  's40 328i tsx c250 jetta',
#  'HUMMER H2',
#  'impala premier 2lz',
#  '760li sedan v12 leather moon 109 service records',
#  'rogue sport',
#  'cruze ls',
#  'traverse ltz awd',
#  'prius five',
#  'durango limited awd gas',
#  'qx80 limited sport',
#  '280z',
#  '2500 laramie',
#  'xjl portfolio',
#  'SAAB 9-3',
#  '330i',
#  'escape se ecoboost',
#  'sante fe',
#  'niro fe',
#  'merceds-benz s-class 550 amg',
#  'custom V8 HEMI convertible',
#  'model s signature',
#  'passat',
#  'acadia denali awd',
#  'f150 lariat 4wd',
#  'e250',
#  'escape 4x4',
#  'vibe',
#  'sienna ce 7 passenger',
#  'corolla l',
#  'f250 super duty lariat',
#  'sierra slt',
#  'TRAVERSE Q50 QX56 FORTE OPTIMA',
#  'q8 3.0t quattro prestige',
#  'g g37 journey sedan 4d',
#  'yukon xl denali',
#  'sorento lx awd',
#  'mdx technology',
#  'santa fe sport utility',
#  'model s',
#  'xt5',
#  'f100',
#  'sierra 2500hd denali',
#  'rlx',
#  'g6 gxp',
#  'sierra 3500hd cc',
#  'xt-4',
#  'cooper, s series',
#  'wrangler unlimited sport',
#  'impreza 2.0i premium',
#  'f-350 super duty flat bed',
#  'tahoe ltz 4x4 gas suv',
#  'tacoma double cab trd',
#  'titan',
#  'e350 4matic',
#  'sierra 1500 limited double',
#  'Mobility MV-1',
#  'silverado 1500 crew c',
#  'fx35',
#  'sienna le',
#  'lifted silverado 3500',
#  'smart fortwo Passion Hatchback',
#  '370z',
#  'escape s',
#  'corolla 4dr sdn cvt le eco (natl)',
#  'gx',
#  '5 series 528i automatic',
#  'f-250 xlt',
#  'golf sportwagen tsi s',
#  'golf alltrack s awd',
#  '1500 quad cab big horn',
#  'ml350',
#  'accord lx',
#  'cherokee sport',
#  'civic del sol',
#  'Plymouth 1/2 Ton',
#  'moutaineer awd',
#  'golf gti',
#  'Maserati Ghibli S Sedan 4D',
#  'fleetwood limo',
#  '1500 crew cab',
#  '1963 MORRIS MINOR WOODY',
#  'q5 premium plus sport',
#  'ascent touring',
#  's60 t5 premier sedan 4d',
#  'e450 bus',
#  'escape se sport suv 4d',
#  'expedition eddie bauer 4wd',
#  'cr-v touring sport utility',
#  'slk 300 roadster',
#  'focus se sedan',
#  'passport',
#  'ISUZU',
#  'sierra duramax 2500 denali',
#  '2500 laramie 4x4 gas',
#  'journey',
#  'f-550 4x4 reg cab fire grass truck utility truck',
#  'taurus limited',
#  'wrangler sahara',
#  'sienna awd',
#  'escape se awd',
#  'sierra 1500 double cab',
#  'journey sxt',
#  'sts',
#  'model 3 long range sedan',
#  'ats luxury sedan 4d',
#  '300 touring',
#  'liberty new sticker',
#  '335i xdrive f30 n55',
#  'rabbit',
#  'm5',
#  'charger buy here pay',
#  'fusion se',
#  'protege',
#  '1500 rebel',
#  'cruze limited 1lt auto',
#  'pickup 2500',
#  'cx-5 sport',
#  'passat vr6 4motion',
#  'eos komfort',
#  'tahoe lt',
#  'ranch wagon',
#  'leaf',
#  'qx80 luxe',
#  'accord ex-l',
#  '650i gran coupe',
#  'gladiator',
#  'sierra 1500 x31 4x4 half ton',
#  'fit',
#  'Scion tC FWD gas Sedan Manual',
#  'cr-v lx suv gas saver ho',
#  'wrx sedan 4d',
#  'cr-v ex-l w/navigation',
#  'transit connect cargo',
#  'sorento sx',
#  'outlander phev sel',
#  'fleetwood',
#  'transit ada wheelchair van',
#  'sonata plug-in hybrid',
#  'mustang shelby',
#  'c-max hybrid se wagon 4d',
#  'explorer xlt sport utility',
#  'gti',
#  'nv 2500',
#  'model 3 standard range',
#  'venza xle',
#  'soul plus',
#  'q5',
#  'sl-class',
#  'rx350 awd',
#  'rx',
#  'silverado 2500 hd',
#  'beetle',
#  '1500 sportextended cab',
#  'tacoma double cab',
#  'express van',
#  'civic coupe',
#  'prius three touring',
#  'wrangler unlimited willys',
#  'miata',
#  'f150 fx2 rwd half ton gas',
#  'rogue sv awd',
#  'challenger r/t coupe 2d',
#  'Isuzu NPR HD REG',
#  'sebring',
#  'Maserati Quattroporte S Q4',
#  'model 3',
#  'accord ex-l v6 sedan',
#  'charger se awd',
#  'scion xa',
#  '328xi xdrive coupe',
#  '750i / alpina b7',
#  'ranger regular cab',
#  '1500 quad cab',
#  'f-250 cargo van',
#  'santa fe sport',
#  'CHEVORLET EXPRESS 3500 1 TON',
#  'envoy',
#  'u Forester',
#  'Scion TC',
#  '740li',
#  'yukon denali',
#  'Victory Kingpin',
#  '535i',
#  'i3 hatchback 4d',
#  'vue',
#  'impala limited lt',
#  'pt cruiser',
#  'frontier 4x4',
#  '2500 crew 4x4',
#  'rl',
#  'x5 xdrive50i',
#  'c-class hybrid',
#  '6 series',
#  'beetle 1.8t s',
#  'xts luxury',
#  'neon',
#  'e-150 transit',
#  'civic touring sedan 4d',
#  '325i',
#  ...]

# %%
X_train_model_bfill_imputed = X_train.copy()
X_train_model_ffill_imputed = X_train.copy()
X_train_model_mode_imputed = X_train.copy()

print(
    X_train_model_bfill_imputed['model'].isnull().any(),
    X_train_model_ffill_imputed['model'].isnull().any(),
    X_train_model_mode_imputed['model'].isnull().any()
)

row_model_with_null_indexes = X_train[X_train['model'].isnull()].index.tolist()

X_train_model_bfill_imputed['model'].bfill(inplace=True)
X_train_model_ffill_imputed['model'].ffill(inplace=True)
X_train_model_mode_imputed['model'].fillna(X_train_model_mode_imputed['model'].mode()[0], inplace=True)

print(
    X_train_model_bfill_imputed['model'].isnull().any(),
    X_train_model_ffill_imputed['model'].isnull().any(),
    X_train_model_mode_imputed['model'].isnull().any()
)

for row_model_with_null_index in row_model_with_null_indexes:
    print(
        X_train_model_bfill_imputed['model'][row_model_with_null_index],
        '------------',
        X_train_model_ffill_imputed['model'][row_model_with_null_index],
        '------------',
        X_train_model_mode_imputed['model'][row_model_with_null_index]
    )
# Out:
# True True True
# False False False
# Junk Cars ------------ gto ------------ f-150
# srx luxury fwd ------------ ilx ------------ f-150
# trailblazer ls ------------ crosstrek 2.0i sport ------------ f-150
# mdx sh-awd w/advance pkg ------------ cr-v ------------ f-150
# s10 ------------ MS250 Mack Midliner ------------ f-150
# silverado 1500 ------------ lr4 hse ------------ f-150
# e-250 ------------ silverado 1500 ------------ f-150
# cooper countryman ------------ sierra 1500 ------------ f-150
# civic ------------ corolla ------------ f-150
# genesis 3.8 sedan 4d ------------ sierra 1500 ------------ f-150
# f-250 sd ------------ silverado ------------ f-150
# tundra crewmax pickup 4d ------------ challenger ------------ f-150
# odyssey ------------ tacoma ------------ f-150
# civic lx ------------ fusion ------------ f-150
# titan platinum reserve ------------ rsx ------------ f-150
# ats premium luxury ------------ benz e320 wagon ------------ f-150
# taurus ------------ charger ------------ f-150
# x5 ------------ c7500 dump truck ------------ f-150
# encore essence sport ------------ cherokee ------------ f-150
# f250 4x4 diesel ------------ sierra ------------ f-150
# pickup ------------ civic natural gas sedan 4d ------------ f-150
# cruze ------------ sonic lt auto ------------ f-150
# charger ------------ mustang ------------ f-150
# malibu ------------ civic ------------ f-150
# milan ------------ explorer ------------ f-150
# wrangler ------------ silverado 3500hd ------------ f-150
# forte ------------ f250 super duty 4x4 ------------ f-150
# benz c320 ------------ accord ------------ f-150
# silverado 1500 ------------ qx80 limited sport ------------ f-150
# mustang ------------ 3 series ------------ f-150
# 1500 crew cab big horn ------------ 1500 ------------ f-150
# f-150 ------------ camry ------------ f-150
# 300 ------------ patriot ------------ f-150
# mustang ------------ sonoma ------------ f-150
# xt4 luxury sport ------------ f-350 crane ------------ f-150
# sierra ------------ 328i awd ------------ f-150
# cherokee ------------ 2500 cummins ------------ f-150
# optima sx ------------ explorer ------------ f-150
# f-750 ------------ yukon denali ------------ f-150
# 300 ------------ mdx technology pkg sport ------------ f-150
# super duty f-250 ------------ soul + ------------ f-150
# cr-v ------------ colorado 4wd z71 ------------ f-150
# yukon ------------ x5 xdrive35d sport utility ------------ f-150
# cayenne gts ------------ c8500 tandem dump truck ------------ f-150
# cayenne gts ------------ c8500 tandem dump truck ------------ f-150
# x5 xdrive 4.8i awd sport-suv ------------ pt cruiser ------------ f-150
# rogue sv sport utility 4 ------------ outback ------------ f-150
# sentra ------------ tlx 2.4 w/technology pkg ------------ f-150
# sierra 1500 ------------ 1500 ------------ f-150
# 3 series ------------ maxima ------------ f-150
# q5 ------------ cr-v exl ------------ f-150
# gla-class gla 45 ------------ terrain sel ------------ f-150
# a4 ------------ accord ------------ f-150
# murano ------------ camry ------------ f-150
# camry ------------ 3 series ------------ f-150
# rx ------------ tl ------------ f-150
# rx ------------ benz e350 ------------ f-150
# deville ------------ a5 ------------ f-150
# civic ------------ santa fe ------------ f-150
# g8 ------------ malibu lt ------------ f-150
# accord ------------ 4runner sr5 sport utility ------------ f-150
# town & country ------------ 1500 crew cab laramie ------------ f-150
# odyssey touring ------------ rav4 base 4x4 local ------------ f-150
# e-class ------------ HUMMER H2 ------------ f-150
# challenger ------------ malibu ------------ f-150
# avalanche black ------------ colorado ------------ f-150
# ats 2.5l ------------ 1974 Argosy Airstream ------------ f-150
# tacoma ------------ explorer ------------ f-150
# f-150 ------------ grand cherokee ------------ f-150
# chr ------------ 2500 ------------ f-150
# fusion se ------------ c-class ------------ f-150
# santa fe ------------ xc60 ------------ f-150
# ranger xlt truck ------------ 1500 ------------ f-150
# element ------------ silverado 1500 ------------ f-150
# cr-v ex-l ------------ durango ------------ f-150
# accent se ------------ f-150 lariat ------------ f-150
# encore ------------ traverse lt ------------ f-150
# clk-class ------------ 3500 ------------ f-150
# tundra sr5 ------------ silverado ------------ f-150
# wrangler unlimited sahara ------------ liteace ------------ f-150
# f-250 ------------ colorado extended cab ------------ f-150
# skyliner ------------ outlander es sport ------------ f-150
# grand caravan se ------------ cr-v ------------ f-150
# v70 2.5t ------------ wrangler ------------ f-150
# wheelchair handicap van ------------ malibu lt sedan 4d ------------ f-150
# 1992 Suzuki Samari ------------ malibu ------------ f-150
# wrangler unlimited ------------ express cutaway 3500 ------------ f-150
# rio s ------------ 4 series 440i xdrive gran ------------ f-150
# impala ------------ silverado ------------ f-150
# 3500 ------------ benz s430 4matic ------------ f-150
# super duty f-350 srw ------------ sierra 2500 hd double cab ------------ f-150
# odyssey ex-l ------------ rav4 ------------ f-150
# accord sport cvt ------------ highlander ------------ f-150
# lucerne ------------ malibu ltz ------------ f-150
# f-450sd ------------ sierra 1500 ------------ f-150
# suburban ------------ tundra crewmax sr5 pickup ------------ f-150
# benz gl450 ------------ expedition ------------ f-150
# a5 ------------ ranger supercab xlt ------------ f-150
# silverado 3500hd ------------ quest sv ------------ f-150
# 3 series 340i sedan 4d ------------ qx50 sport utility 4d ------------ f-150
# traverse ------------ cr-v ------------ f-150
# nitro ------------ xe p300 r-dynamic s sedan ------------ f-150
# impala ltz ------------ f-350 ------------ f-150
# tuarus se ------------ 3 series 330i xdrive sedan ------------ f-150
# explorer ------------ model s signature ------------ f-150
# versa ------------ highlander ------------ f-150
# f250 crew 4x4 ------------ compass sport ------------ f-150
# Enclave ------------ milan ------------ f-150
# rav4 sport utility 4d ------------ m35 ------------ f-150
# xf 20d premium sedan 4d ------------ z4 sdrive35is roadster 2d ------------ f-150
# rx 330 ------------ civic ------------ f-150
# impala ------------ Freightliner M2 ------------ f-150
# town & country ------------ civic ------------ f-150
# sportage ------------ yukon ------------ f-150
# fusion ------------ sierra ------------ f-150
# pilot ------------ tundra 2wd truck ------------ f-150
# olet Silverado 3500HD CC ------------ wrangler rhd 1 owner ------------ f-150
# escape xls ------------ rav4 ------------ f-150
# tacoma double cab trd ------------ mustang ------------ f-150
# promaster city wagon ------------ matrix ------------ f-150
# murano ------------ a4 ------------ f-150
# transit 250 ------------ f150 ------------ f-150
# corolla im ------------ x5m ------------ f-150
# fj40 ------------ f250 super duty ------------ f-150
# f350 super duty crew cab ------------ f150 lariat 4x4 1/2 ton gas ------------ f-150
# corvair monza ------------ escape xlt ------------ f-150
# FREIGHTLINER M2 Service Truck w ------------ x5 xdrive35i ------------ f-150
# mdx advance pkg sport ------------ sierra denali ------------ f-150
# ats sedan ------------ m37 ------------ f-150
# 1500 classic ------------ patriot sport suv 4x4 ------------ f-150
# mkz select sedan 4d ------------ trax ------------ f-150
# taurus se ------------ rdx ------------ f-150
# avalanche ------------ grand cherokee ------------ f-150
# trailblazer ext ------------ spark ev 2lt hatchback ------------ f-150
# versa note ------------ edge limited awd ------------ f-150
# x3 xdrive30i sport utility ------------ silverado 1500 ------------ f-150
# journey sxt ------------ impala ------------ f-150
# camry ------------ tahoe ------------ f-150
# model 3 standard range ------------ highlander limited ------------ f-150
# equinox ------------ impala ------------ f-150
# f-550 ------------ rogue ------------ f-150
# camaro ss coupe 2d ------------ mdx sh-awd w/technology ------------ f-150
# rav4 ------------ is 250 ------------ f-150
# explorer ------------ silverado ------------ f-150
# s-type ------------ 2500hd ------------ f-150
# silverado 1500 ------------ tacoma ------------ f-150
# f250 super duty ------------ mdx advance pkg sport ------------ f-150
# santa fe ------------ accord ------------ f-150
# sport ------------ santa fe ------------ f-150
# f150 stx 4x4 ------------ silverado 1500 ------------ f-150
# f-150 ------------ f450 ------------ f-150
# a8 l 4dr sdn 3.0t ------------ f-150 ------------ f-150
# silverado ------------ tlx 3.5 w/technology pkg ------------ f-150
# sierra 1500 crew cab slt ------------ outlander sport ------------ f-150
# crosstour ------------ tl ------------ f-150
# silverado 1500 crew ------------ mustang ------------ f-150
# WATER TRUCK ------------ durango ------------ f-150
# 325i ------------ mustang ------------ f-150
# 55 Crown Victoria ------------ series 5 535i ------------ f-150
# cobalt ------------ other ------------ f-150
# rav4 ------------ super duty f-350 drw ------------ f-150
# 4runner ------------ crown victoria ------------ f-150
# tlx 2.4 sedan 4d ------------ rav4 ------------ f-150
# silverado 2500 ------------ silverado 1500 ltz ------------ f-150
# tl sedan 4d ------------ expedition ------------ f-150
# escalade esv ------------ m3 sedan 4d ------------ f-150
# vue ------------ dart limited ------------ f-150
# transit cargo ------------ f-150 ------------ f-150
# wrangler 4x4 ------------ explorer ------------ f-150
# 1500 ------------ beetle ------------ f-150
# f350 super duty ------------ acadia ------------ f-150
# outlander sport ------------ murano ------------ f-150
# s4 premium plus sedan 4d ------------ mkz reserve hybrid sedan ------------ f-150
# canyon ------------ a4 ------------ f-150
# m-class ml 350 4m ------------ q5 ------------ f-150
# tacoma trd off-road ------------ Genesis G70 3.3T Dynamic Edition ------------ f-150
# focus ------------ rogue ------------ f-150
# cooper ------------ camry se automatic ------------ f-150
# silverado 1500 double ------------ wrangler jk unlimited ------------ f-150
# silverado 1500 double ------------ wrangler jk unlimited ------------ f-150
# mdx sh-awd w/technology ------------ rx 330 ------------ f-150
# cr-v ------------ 3 series 340i sedan 4d ------------ f-150
# mdx sh-awd w/technology ------------ tacoma access cab sr ------------ f-150
# g35 journey ------------ silverado ------------ f-150
# f-150 xlt fx4 ------------ coe ------------ f-150
# mazda6 i sport sedan 4d ------------ dakota ------------ f-150
# cayenne ------------ suburban ------------ f-150
# silverado 1500 ------------ explorer ------------ f-150
# sonata gls ------------ a3 sportback e-tron ------------ f-150
# 3500 ------------ accord lx ------------ f-150
# mazda6 ------------ prius hybrid ------------ f-150
# edge ------------ f150 supercrew cab xl ------------ f-150
# sorento ------------ suburban ------------ f-150
# benz c300 4matic ------------ sorento ------------ f-150
# edge ------------ colorado crew cab lt ------------ f-150
# liberty renegade ------------ 3500 cutaway van ------------ f-150
# pickup 2500 sltquad ------------ 3 series 340i sedan 4d ------------ f-150
# Scion xB ------------ 3 series ------------ f-150
# forester (natl) ------------ 1500 harvest ------------ f-150
# caliber r/t ------------ scion xd ------------ f-150
# 1500 crew cab big horn ------------ camaro ------------ f-150
# qx60 luxe sport utility ------------ tacoma trd off road ------------ f-150
# avalanche ------------ grand caravan ------------ f-150
# a6 quattro ------------ tacoma ------------ f-150
# silverado 1500 ------------ sierra ------------ f-150
# 2500 ------------ wrangler 392 ------------ f-150
# f-150 ------------ Maserati Ghibli ------------ f-150
# sienna xle awd ------------ e-class e 400 ------------ f-150
# 4 series ------------ corolla le sedan 4d ------------ f-150
# f-150 ------------ sprinter 3500 ------------ f-150
# impreza 2.0i sport wagon ------------ traverse ------------ f-150
# mdx sport utility 4d ------------ WORKHORSE W42 ------------ f-150
# terrain ------------ fusion hybrid ------------ f-150
# glc 300 sport ------------ 428 xdrive awd gas sedan ------------ f-150
# malibu ------------ murano ------------ f-150
# xc60 ------------ journey ------------ f-150
# cr-v ------------ patriot ------------ f-150
# silverado ------------ durango slt ------------ f-150
# camaro ss coupe 2d ------------ thunderbird ------------ f-150
# f-250 ------------ wrangler unlimited rubicon ------------ f-150
# escape ------------ f750 xl ------------ f-150
# wrangler rubicon sport ------------ sierra 1500 regular cab ------------ f-150
# super duty f-250 srw 4wd crew cab 156" xlt ------------ beetle 1.8t fleet ------------ f-150
# outlander sport es ------------ sierra 1500 ------------ f-150
# edge ------------ focus ------------ f-150
# 86 trd special edition ------------ accord ex ------------ f-150
# romeo stelvio sport suv 4d ------------ wrangler/tj ------------ f-150
# Genesis G70 2.0T Sedan 4D ------------ 1500 regular cab tradesman ------------ f-150
# canyon extended cab pickup ------------ f350 ------------ f-150
# flex se sport utility 4d ------------ x3 sdrive30i sport utility ------------ f-150
# outlander sport ------------ tahoe ------------ f-150
# sequoia sr5 ------------ atlas s 4motion sport ------------ f-150
# f-250 super duty xlt lifted crew ------------ express commercial cutaway ------------ f-150
# civic lx sedan 4d ------------ elantra sel ------------ f-150
# accord ------------ f-150 ------------ f-150
# benz s550 ------------ es 350 ------------ f-150
# challenger ------------ sierra ------------ f-150
# jetta ------------ 5 series ------------ f-150
# cr-v ------------ focus st hatchback 4d ------------ f-150
# f-250 super duty ------------ c-max hybrid ------------ f-150
# silverado ------------ f550 ------------ f-150
# 3500 ------------ focus ------------ f-150
# m3 convertible 2d ------------ edge ------------ f-150
# c-class c 300 ------------ volt ------------ f-150
# f-150 ------------ mx-5 miata ------------ f-150
# SS 117 ------------ e-class ------------ f-150
# wrangler ------------ hhr ------------ f-150
# mustang gt coupe 2d ------------ f-150 supercrew lariat 4x4 ------------ f-150
# sierra durmax 3500 hd all ------------ 300 300s sedan 4d ------------ f-150
# 2500 ------------ avalon xl/xls ------------ f-150
# golf 1.4t tsi ------------ ct4 ------------ f-150
# outback 2.5i limited ------------ kenworth t800 ------------ f-150
# tahoe ------------ sedan ------------ f-150
# s-class ------------ 528i ------------ f-150
# expedition ------------ mustang boss 302 coupe 2d ------------ f-150
# f150 ------------ compass ------------ f-150
# mx-5 miata grand touring ------------ rav4 ------------ f-150
# veloster n coupe 3d ------------ wrangler rubicon ------------ f-150
# camry le 6-spd mt ------------ edge ------------ f-150
# silverado 1500 ltz ------------ sentra ------------ f-150
# cherokee latitude ------------ rav4 ------------ f-150
# bronco ------------ promaster city cargo ------------ f-150
# q50 ------------ ct ------------ f-150
# transit ------------ accord ex ------------ f-150
# tlx ------------ challenger sxt coupe ------------ f-150
# es 350 sedan 4d ------------ tiguan ------------ f-150
# fit ------------ es 350 sedan 4d ------------ f-150
# baja bug ------------ beetle ------------ f-150
# REX ------------ cruze limited ------------ f-150
# impreza 2.0i awd ------------ tahoe ------------ f-150
# smart fortwo Passion Hatchback ------------ impreza 2.0i sport wagon ------------ f-150
# 1500 ------------ f-150 fx4 ------------ f-150
# f450 xl ------------ mkx ------------ f-150
# jimmy ------------ accord ------------ f-150
# continental ------------ traverse lt awd ------------ f-150
# x1 ------------ cruze lt diesel ------------ f-150
# encore gx select sport ------------ encore gx select sport ------------ f-150
# 1500 big horn ------------ silverado 1500 ld ------------ f-150
# silverado ------------ accord ex-l ------------ f-150
# f-150 xlt ------------ navigator premiere sport ------------ f-150
# a6 ------------ compass limited ------------ f-150
# town & country ------------ 1500 classic regular cab ------------ f-150
# 1500 quad cab ------------ pilot ex-l w/res sport ------------ f-150
# deville ------------ tacoma ------------ f-150
# ranger super cab xlt pickup ------------ wrangler unlimited all new ------------ f-150
# taurus sel awd ------------ rogue ------------ f-150
# sorento ------------ 328i ------------ f-150
# 944 ------------ 3500 laramie ------------ f-150
# grand caravan ------------ escape ------------ f-150
# colorado extended cab ------------ rio ------------ f-150
# focus ------------ es 300 base ------------ f-150
# charger ------------ grand caravan ------------ f-150
# m35x awd ------------ cl63 amg ------------ f-150
# 550i gran turismo 550i ------------ wrangler unlimited rubicon ------------ f-150
# taurus limited ------------ s-class ------------ f-150
# impala ltz ------------ equinox ------------ f-150
# gladiator rubicon only 9k ------------ a7 ------------ f-150
# x6 xdrive35i sport utility ------------ traverse ------------ f-150
# lucerne ------------ f-150 ------------ f-150
# jetta 1.4t s sedan 4d ------------ 3 series ------------ f-150
# civic ------------ silverado 2500hd ------------ f-150
# pickup 1500 classic ------------ 2500 ------------ f-150
# tacoma ------------ celica gt ------------ f-150
# fusion se ------------ mkx select sport utility ------------ f-150
# 1500 ------------ sierra 3500hd sle ------------ f-150
# elantra gls ------------ q50 ------------ f-150
# 200 ------------ rx 330 ------------ f-150
# silverado 1500 lt ------------ 240sx se ------------ f-150
# silverado 1500 double ------------ challenger ------------ f-150
# silverado 1500 ------------ sequoia 4wd platinum ------------ f-150
# escalade esv ------------ z4 ------------ f-150
# yukon denali ------------ altima ------------ f-150
# 4-runner ------------ beetle 1.8t fleet ------------ f-150
# silverado 2500 ltz du ------------ jetta sportwagen tdi ------------ f-150
# corvette ------------ rx350 ------------ f-150
# enclave premium sport ------------ 5 series 535i ------------ f-150
# mdx sh-awd sport utility ------------ fusion ------------ f-150
# equus signature sedan 4d ------------ 1500 ------------ f-150
# gs 350 ------------ tiguan ------------ f-150
# f-250 super duty ------------ sorento ------------ f-150
# f-250 super duty ------------ G.M. ------------ f-150
# challenger r/t rwd gas ------------ 2500 crew cab slt 4x4 ------------ f-150
# OLDSMOBILE BRAVADA ------------ 3 series ------------ f-150
# g5 gt ------------ rdx advance pkg sport ------------ f-150
# cts 2.0 ------------ dakota quad cab sport 3.7 ------------ f-150
# metris passenger ------------ s60 t5 premier plus sedan ------------ f-150
# tahoe ------------ sebring ------------ f-150
# cr-v ------------ rogue s ------------ f-150
# nv2500 hd cargo ------------ sierra 1500 sle 4x4 ------------ f-150
# focus ------------ oldsmobile alero ------------ f-150
# nv2500 highroof ------------ x3 ------------ f-150
# STERLING L ------------ f-350sd ------------ f-150
# sportage lx sport utility ------------ cruze ------------ f-150
# accord ------------ xv crosstrek 5dr cvt 2.0 ------------ f-150
# 16M ------------ 3500 st ------------ f-150
# sierra 1500 crew cab slt ------------ sentra ------------ f-150
# edge ------------ journey se ------------ f-150
# Accord ------------ corolla le ------------ f-150
# 3500 ------------ silverado ------------ f-150
# e-150 ------------ soul ------------ f-150
# murano s ------------ eos sport convertible ------------ f-150
# mustang ------------ vue ------------ f-150
# express commercial cutaway ------------ 4500 ------------ f-150
# venza xle wagon 4d ------------ 1500 quad cab ------------ f-150
# comet ------------ 3500 tradesman ------------ f-150
# rogue s sport utility 4d ------------ s5 premium plus convertible ------------ f-150
# nitro ------------ cherokee latitude ------------ f-150
# f-150 ------------ colorado ------------ f-150
# 2020 ------------ dart gt ------------ f-150
# wrangler ------------ f-150 ------------ f-150
# outlander sport es ------------ pilot ------------ f-150
# tiguan ------------ escape ------------ f-150
# impala ------------ sonata se sedan 4d ------------ f-150
# explorer sport automatic ------------ fiesta ------------ f-150
# civic ------------ soul ------------ f-150
# civic ------------ soul ------------ f-150
# mazda3 ------------ yukon xl ------------ f-150
# tsx wagon 4d ------------ corvette ------------ f-150
# highlander hybrid le ------------ mkx ------------ f-150
# corvette ------------ pilot ------------ f-150
# tundra double cab sr ------------ crown victoria police ------------ f-150
# avalanche ------------ golf ------------ f-150
# xk ------------ 1500 crew cab big horn ------------ f-150
# impala ------------ colorado extended cab ------------ f-150
# sprinter 2500 ------------ ion ------------ f-150
# camaro berlinetta ------------ murano ------------ f-150
# tacoma access cab pickup ------------ yukon ------------ f-150
# enclave ------------ mustang ------------ f-150
# allroad ------------ edge ------------ f-150
# 1500 ------------ cherokee 4x4 ------------ f-150
# explorer ------------ prius ------------ f-150
# silverado ------------ escape ------------ f-150
# explorer ------------ f350 ------------ f-150
# 3500 slt ------------ sonata ------------ f-150
# impala ------------ compass ------------ f-150
# ls ------------ accord ------------ f-150
# 1500 ------------ odyssey ex-l ------------ f-150
# silverado ltz crew ca ------------ f-350 ------------ f-150
# fusion ------------ journey ------------ f-150
# soul s wagon 4d ------------ rogue ------------ f-150
# a4 convertible ------------ new passat ------------ f-150
# mustang convertible ------------ sportage ------------ f-150
# f350 super duty ------------ focus se ------------ f-150
# super duty f-550 drw ------------ wrangler unlimited ------------ f-150
# transit cargo van ------------ olet Silverado 1500 ------------ f-150
# range evoque pure ------------ expedition xlt sport ------------ f-150
# s-class s ------------ sierra 2500hd ------------ f-150
# fusion ------------ srx ------------ f-150
# focus se 4d sedan ------------ s80 2.5t ------------ f-150
# acadia denali ------------ sebring ------------ f-150
# silverado 1500 ------------ g35 ------------ f-150
# camaro zl1 super charged v-8 1900 miles!!! ------------ fusion ------------ f-150
# sierra 2500hd ------------ sierra ------------ f-150
# durango sxt sport utility ------------ camry ------------ f-150
# explorer sport trac ------------ suzuki reno ------------ f-150
# escape ------------ wrangler ------------ f-150
# escape ------------ wrangler ------------ f-150
# ecosport titanium ------------ veloster ------------ f-150
# xc60 t6 awd ------------ sierra denali ------------ f-150
# f-150 ------------ outlander sport es ------------ f-150
# sportage lx ------------ f-150 ------------ f-150
# 1500 express 4x4 gas ------------ 3 series 335d sedan 4d ------------ f-150
# xt4 sport suv 4d ------------ MASTERCRAFT ------------ f-150
# romeo stelvio ti sport ------------ escalade platinum sport ------------ f-150
# jetta gli 35th ------------ x5 ------------ f-150
# expedition ------------ equinox ------------ f-150
# civic ------------ 1500 ------------ f-150
# impala ------------ savana 3500 dual wheels ------------ f-150
# atlas se 4motion ------------ 1500 sport rwd 1/2 ton ------------ f-150
# accord ------------ sentra ------------ f-150
# outback wagon ------------ 528xi ------------ f-150
# dart sxt ------------ wrangler unlimited sport ------------ f-150
# avalon ------------ 5 sport ------------ f-150
# 2500 ------------ express cargo van ------------ f-150
# terrain sle awd! awd ------------ soul base ------------ f-150
# 4runner ------------ dart ------------ f-150
# colorado lt ------------ wrangler unlimited ------------ f-150
# gs gs 350 rwd ------------ 750i ------------ f-150
# rav 4 awd ------------ mks ------------ f-150
# sienna xle ny ------------ silverado 1500 ------------ f-150
# f350 ------------ land cruiser ------------ f-150
# express conversion van ------------ prius ------------ f-150
# p30 ------------ f150 ------------ f-150
# f350 diesel dualy ------------ sentra ------------ f-150
# f-150 ------------ g6 ------------ f-150
# a4 s line se 2.0t ------------ f-150 ------------ f-150
# grand cherokee 4wd 4dr laredo ------------ sierra 1500 ------------ f-150
# venue sel sport utility ------------ f-250 super duty ------------ f-150
# odyssey ------------ yukon ------------ f-150
# cls-class cls 550 ------------ rav4 ------------ f-150
# golf gti s hatchback ------------ sonata ------------ f-150
# ion ------------ cruze ------------ f-150
# rav4 xle ------------ Nissan-34 MPG!! AUTO! BLACK BEAUTY! Sentra-BHPH! ------------ f-150
# wrangler jk unlimited sport ------------ Maserati Ghibli S Q4 Sedan 4D ------------ f-150
# civic ------------ silverado 1500 lt 4x4 ------------ f-150
# gs 350 ------------ lancer evolution ------------ f-150
# m-class ml 350 ------------ liberty ------------ f-150
# 1500 sxt 4x4 ------------ business coupe ------------ f-150
# forte ------------ econoline commercial cutaway ------------ f-150
# x5 ------------ all make and modles ------------ f-150
# srx ------------ grand caravan - stow 'n go - flex fuel - new tires ------------ f-150
# accord lx ------------ ierra 1500 ------------ f-150
# civic ------------ sierra 1500 ------------ f-150
# grand cherokee ------------ q8 premium sport utility 4d ------------ f-150
# f150 ------------ super duty f-350 srw ------------ f-150
# elantra ------------ e 400 ------------ f-150
# tacoma ------------ f-150 ------------ f-150
# coupe ------------ f-150 ------------ f-150
# forester 2.5x wagon ------------ altima ------------ f-150
# cherokee ------------ mirage se ------------ f-150
# highlander ------------ q7 ------------ f-150
# taurus ------------ land cruiser prado ------------ f-150
# eclipse cross es 4x4 ------------ highlander limited ------------ f-150
# malibu ltz ------------ impreza wagon ------------ f-150
# corolla ------------ cx-5 ------------ f-150
# q50 3.0t luxe sedan 4d ------------ f-150 ------------ f-150
# Utilimaster Step Van ------------ hhr ------------ f-150
# torrent base ------------ q60 3.0t sport coupe 2d ------------ f-150
# outlander phev sel ------------ grand caravan ------------ f-150
# kodiak 4500 ------------ mazda3 ------------ f-150
# ilx luxury ------------ matrix ------------ f-150
# q3 ------------ international ------------ f-150
# mazda3 ------------ aveo ------------ f-150
# gls new beetle convertible ------------ prius ------------ f-150
# explorer ------------ genesis coupe 3.8 2d ------------ f-150
# frontier ------------ cts ------------ f-150
# f250 super duty ------------ x5 sdrive35i ------------ f-150
# f150 super cab xl pickup 4d ------------ grand caravan sxt ------------ f-150
# corvette ------------ impala lt sedan 4d ------------ f-150
# hhr lt ------------ mustang ecoboost rwd gas ------------ f-150
# colorado crew cab lt ------------ wrangler jk ------------ f-150
# colorado crew cab lt ------------ wrangler jk ------------ f-150
# cruze limited ------------ cj7 ------------ f-150
# xt5 sport suv 4d ------------ grand cherokee ------------ f-150
# spark activ hatchback ------------ 3500 ------------ f-150
# uplander lt ------------ legacy limited 3.6r ------------ f-150
# cls ------------ rogue ------------ f-150
# cherokee trailhawk sport ------------ silverado 3500 high c ------------ f-150
# camaro ------------ civic ------------ f-150
# cts 2.0 luxury ------------ impreza ------------ f-150
# f-350 super duty ------------ sport ------------ f-150
# sable ------------ f-150 xlt supercrew 4x4 ------------ f-150
# x5 ------------ aura ------------ f-150
# cx-5 touring ------------ c 300 ------------ f-150
# cruze ------------ ct200h f sport ------------ f-150
# charger srt hellcat ------------ rogue sport sv ------------ f-150
# yukon ------------ glk ------------ f-150
# odyssey ------------ forester ------------ f-150
# tl ------------ expedition eddie bauer ------------ f-150
# camaro ------------ f250 super duty 4x4 ------------ f-150
# new sierra crew cab 1500 ------------ jetta ------------ f-150
# optima ------------ new sierra crew cab 1500 ------------ f-150
# f-150 ------------ wrangler unlimited sport ------------ f-150
# outlander sport ------------ tucson ------------ f-150
# ridgeline sport pickup 4d ------------ sonata ------------ f-150
# enclave premium sport ------------ cx-5 ------------ f-150
# transit t250 ------------ s80 ------------ f-150
# regal preferred ii ------------ highlander ------------ f-150
# silverado 1500 lt z71 ------------ silverado 1500 ------------ f-150
# veloster ------------ 328xi ------------ f-150
# santa fe ------------ silverado 2500hd ------------ f-150
# f-150 ------------ terrain ------------ f-150
# bronco ------------ es 300h sedan 4d ------------ f-150
# 9-3 2.OT CPNV/342 ------------ tacoma access cab pickup ------------ f-150
# versa ------------ savana ------------ f-150
# maxima sv (2017.5) sedan ------------ f150 ------------ f-150
# ranger fx4 offroad ------------ 6 ------------ f-150
# tacoma ------------ tacoma ------------ f-150
# challengers ------------ Scion TC ------------ f-150
# qx56 ------------ ranger xlt ------------ f-150
# sierra 1500 ------------ f-150 ------------ f-150
# f-150 ------------ avalanche 4x4 ------------ f-150
# f-250 ------------ apache ------------ f-150
# sentra ------------ navigator ------------ f-150
# traverse ------------ patriot ------------ f-150
# camaro z28 ------------ Hudson Pick up ------------ f-150
# f150 supercrew cab lariat ------------ 4runner sr5 ------------ f-150
# fusion titanium ecoboost i4 fwd ------------ silverado 1500 ------------ f-150
# grand cherokee ------------ civic si coupe ------------ f-150
# 1500 ------------ silverado 2500 diesel 4x4 6.6l lmm duramax turbo diesel crew cab long bed allison 1000 ltz ------------ f-150
# accord lx ------------ f-150 ------------ f-150
# g37x ------------ f150 super cab stx pickup ------------ f-150
# wrangler ------------ sentra ------------ f-150
# optima ------------ traverse lt ------------ f-150
# sequoia ------------ dts ------------ f-150
# wrangler ------------ silverado ------------ f-150
# super duty f-250 srw ------------ s5 prestige sedan 4d ------------ f-150
# camry ------------ rogue ------------ f-150
# 5 series 530i xdrive sedan ------------ allroad prestige wagon 4d ------------ f-150
# wrangler unlimited all new ------------ silverado ------------ f-150
# impala ------------ cruze ------------ f-150
# sierra ------------ rx300 ------------ f-150
# sequoia ------------ frontier sv ------------ f-150
# f550 4x4 ------------ journey ------------ f-150
# golf ------------ sentra ------------ f-150
# encore ------------ enclave ------------ f-150
# silverado 3500hd ------------ CX-9 ------------ f-150
# crossfire ------------ outback ------------ f-150
# f150 ------------ prius hybrid ------------ f-150
# rdx ------------ forte sx ------------ f-150
# patriot ------------ 3 series ------------ f-150
# sierra 1500 ------------ tribute ------------ f-150
# grand caravan sxt ------------ wrangler ------------ f-150
# q50 3.0t sport sedan 4d ------------ f-250 ------------ f-150
# q50 3.0t sport sedan 4d ------------ f-250 ------------ f-150
# g37 awd ------------ ls430 ------------ f-150
# crv ------------ camaro ss coupe 2d ------------ f-150
# 328i ------------ silverado 1500 lt ------------ f-150
# tahoe ltz 4x4 ------------ forester ------------ f-150
# tundra sr5 4x4 1/2 ton ------------ odyssey ex-l ------------ f-150
# civic ex ------------ e-class ------------ f-150
# a4 allroad premium plus ------------ colorado crew cab z71 ------------ f-150
# benz e300 ------------ yukon ------------ f-150
# ml 350 ------------ pilot ------------ f-150
# journey se - certified one ------------ silverado 1500 crew ------------ f-150
# town & country touring ------------ grand caravan ------------ f-150
# grand cherokee ------------ soul ------------ f-150
# MUSTANH ------------ corolla ------------ f-150
# f150 ------------ regal ------------ f-150
# 4runner limited 4x4 ------------ 1500 crew cab big horn ------------ f-150
# iNTERNATIONAL ------------ tlx awd ------------ f-150
# grand cherokee ------------ wrangler jk unlimited ------------ f-150
# enclave cxl ------------ outlander phev gt ------------ f-150
# all cars ------------ legacy ------------ f-150
# rx ------------ vibe ------------ f-150
# sienna ------------ ux 250h sport utility 4d ------------ f-150
# 3500 ------------ express cargo ------------ f-150
# transit ------------ patriot ------------ f-150
# a4 ------------ CountryAuto ------------ f-150
# g37 ------------ sentra ------------ f-150
# traverse ------------ c-class ------------ f-150
# VMI-CHRYSLER-♿ ------------ encore ------------ f-150
# elantra ------------ solara se convertible ------------ f-150
# f-150 ------------ explorer sport trac ------------ f-150
# f350 crew cab 4x4 flat bed ------------ silverado duramax hd ------------ f-150
# altima 2.5 s ------------ lacrosse ------------ f-150
# corolla im hatchback 4d ------------ f-150 xlt ------------ f-150
# bolt ev premier ------------ xjs ------------ f-150
# bolt ev premier ------------ xjs ------------ f-150
# 1500 4wd ------------ 330i ------------ f-150
# tacoma double cab 4x4 ------------ civic ------------ f-150
# sierra 1500 hybrid ------------ maxima ------------ f-150
# gx 460 ------------ altima ------------ f-150
# malibu ------------ nv200 ------------ f-150
# focus hatchback ------------ edge ------------ f-150
# f-150 ------------ odyssey ex-l ------------ f-150
# f-150 ------------ odyssey ex-l ------------ f-150
# tundra 1794 edition ------------ prius c ------------ f-150
# odyssey touring ------------ super duty f-350 drw ------------ f-150
# flex ------------ clk-class ------------ f-150
# 5 series ------------ equinox lt ------------ f-150
# optima lx 4d sedan automatic ------------ sentra 2.0 sr ------------ f-150
# yukon ------------ civic dx sedan ------------ f-150
# x3 ------------ 7-series ------------ f-150
# avalon ------------ sierra 3500 denali ------------ f-150
# aveo ------------ Mazda3 ------------ f-150
# 4-runner ------------ benz s500 ------------ f-150
# 2500 ------------ f150 lariat sport 4x4 gas ------------ f-150
# xts luxury sedan 4d ------------ Genesis G80 3.8 Sedan 4D ------------ f-150
# silverado 1500 regular ------------ panamera 4 ------------ f-150
# 2500 mega cab lifted ------------ mustang gt coupe 2d ------------ f-150
# transit connect xlt ------------ legacy 2.5i ------------ f-150
# 2500 quad cab ------------ chieftain ------------ f-150
# q60 3.0t premium coupe ------------ wrangler unlimited rubicon ------------ f-150
# allroad prestige wagon 4d ------------ civic ------------ f-150
# q50 3.0t luxe sedan 4d ------------ cr-v ------------ f-150
# tacoma sr5 rwd 1/4 ton ------------ edge ------------ f-150
# tundra 2wd truck ------------ journey ------------ f-150
# 3 series ------------ z4 sdrive30i roadster 2d ------------ f-150
# santa fe sport ------------ 428i convertible ------------ f-150
# suburban premier ------------ edge ------------ f-150
# Isuzu NPR ------------ biscayne ------------ f-150
# camaro ls coupe 2d ------------ rx 350 ------------ f-150
# envision ------------ grand caravan ------------ f-150
# 1500 ------------ 2500 diesel ------------ f-150
# golf alltrack tsi s ------------ foreter 2.5i premium ------------ f-150
# grand cherokee ------------ tiguan ------------ f-150
# challenger srt8 coupe 2d ------------ cr-v lx suv gas saver ho ------------ f-150
# civic sport sedan 4d ------------ 3500 ------------ f-150
# tundra double cab sr ------------ corolla ------------ f-150
# wrangler ------------ wrangler ------------ f-150
# xc70 ------------ rx ------------ f-150
# accord ex-l *fr $499 down guaranteed finance ------------ 4runner sr5 **4wd** ------------ f-150
# f-250 ------------ charger ------------ f-150
# optima ------------ f150 supercrew cab lariat ------------ f-150
# prius four touring ------------ suburban 1500 ------------ f-150
# tlx ------------ silverado ------------ f-150
# impreza outback ------------ c-class ------------ f-150
# impreza outback ------------ c-class ------------ f-150
# CHEVEROLET SONIC ------------ cf8000 ------------ f-150
# protege5 ------------ tacoma ------------ f-150
# wrangler unlimited ------------ cherokee ------------ f-150
# equinox ------------ c-class ------------ f-150
# traverse ------------ 1987 international ------------ f-150
# benz ------------ explorer ------------ f-150
# mustang gt coupe 2d ------------ highlander ------------ f-150
# prius ------------ sentra ------------ f-150
# flatbed truck ------------ charger ------------ f-150
# countryman cooper se all4 ------------ 1500 4x4 ------------ f-150
# pilot ------------ es300 ------------ f-150
# x6 xdrive35i sport utility ------------ pilot ------------ f-150
# volt ------------ f-350 diesel ------------ f-150
# explorer xlt ------------ camry ------------ f-150
# boxster ------------ g37 coupe ------------ f-150
# f-150 ------------ wrangler sport suv 2d ------------ f-150
# studebaker hawk ------------ escalade ------------ f-150
# f-150 ------------ passat ------------ f-150
# tahoe lt ------------ wrangler unlimited ------------ f-150
# f-350 ------------ f-150 ------------ f-150
# yukon xl ------------ f-350 ------------ f-150
# silverado 2500hd high ------------ sierra 1500 sltextended ------------ f-150
# f-350 sd ------------ Mack ------------ f-150
# rogue ------------ liteace ------------ f-150
# davidson ------------ silverado 1500 ld ------------ f-150
# silverado 1500 ------------ beetle fender edition ------------ f-150
# Chevelle ------------ s60 t5 premier sedan 4d ------------ f-150
# 3500 laramie ------------ International CF500 ------------ f-150
# 2016 Cevy silverado 1500 ------------ 535i ------------ f-150
# cls ------------ international 4300 ------------ f-150
# pacifica l ------------ gx 470 ------------ f-150
# g 20 ------------ sorento ------------ f-150
# silverado ------------ 2500 ------------ f-150
# town and country ------------ sentra ------------ f-150
# taurus ------------ acadia ------------ f-150
# saab 9-5 ------------ avalanche ------------ f-150
# sierra 1500 ------------ escalade esv ------------ f-150
# elantra ------------ camaro lt coupe 2d ------------ f-150
# maxima ------------ enclave cxl ------------ f-150
# acadia slt awd ------------ transit connect van ------------ f-150
# countryman ------------ f150 lariat ------------ f-150
# sierra 2500hd denali ------------ tribeca ------------ f-150
# renegade limited 4x4 gas ------------ optima ------------ f-150
# xc60 local lots of records ------------ q5 3.0t premium plus sport ------------ f-150
# silverado ------------ 3100 5 window ------------ f-150
# 7 series 740e xdrive sedan ------------ silverado 3500 high c ------------ f-150
# journey sxt ------------ f-350 ------------ f-150
# journey sxt ------------ f-350 ------------ f-150
# camaro ------------ ranger ------------ f-150
# cooper countryman ------------ outlander sel sport ------------ f-150
# f350 diesel powerstroke 4x4 ------------ civic hybrid ------------ f-150
# equinox ------------ pilot touring sport ------------ f-150
# 3 series 328d xdrive sport ------------ mazda5 ------------ f-150
# patriot sport **only 22k miles*automatic air conditioning ------------ camry hybrid sedan ------------ f-150
# civic si ------------ equinox ------------ f-150
# silverado 2500 ------------ cheverlet corvette ------------ f-150
# tundra 2wd truck ------------ transit ------------ f-150
# f-150 fx4 4wd!crew cab ------------ rav4 ------------ f-150
# sierra 1500 extended cab slt ------------ sierra 1500 limited double ------------ f-150
# edge sel awd ------------ cobalt ------------ f-150
# frontier sv 4x4 ------------ silverado 2500 lt 4x4 ------------ f-150
# escape ------------ 300 limited sedan 4d ------------ f-150
# suburban ltz 4x4 ------------ sierra 3500 ------------ f-150
# benz cla 250 ------------ commander ------------ f-150
# grand caravan se wheelcha ------------ tahoe lt ------------ f-150
# grand prix ------------ outlander ------------ f-150
# odyssey ------------ cherokee ------------ f-150
# oldsmobile cutlass convertible ------------ silverado 1500 ------------ f-150
# altima ------------ sentra ------------ f-150
# ilx premium pkg sedan 4d ------------ sienna le ------------ f-150
# cc4500 ------------ 124 spider classica ------------ f-150
# rl sh-awd ------------ 4runner trd off road 4x4 ------------ f-150
# equinox ------------ 1500 ------------ f-150
# International 4300 ------------ civic si ------------ f-150
# town & country ------------ x5 ------------ f-150
# edge titanium awd 4dr ------------ camry ------------ f-150
# outlander ------------ Mazda3 ------------ f-150
# International ------------ jetta sedan ------------ f-150
# romeo stelvio ti sport suv ------------ f-150 xlt 4x4 ------------ f-150
# town car ------------ edge sel ------------ f-150
# sierra durmax 2500 hd slt ------------ silverado ------------ f-150
# colorado zr2 ------------ CHRSYLER TOWN & COUNTRY ------------ f-150
# camry le ------------ f150 supercrew cab lariat ------------ f-150
# traverse ------------ 2017 ------------ f-150
# tacoma ------------ 335i ------------ f-150
# 5 series 535i sedan 4d ------------ tundra ------------ f-150
# town car ------------ f150 regular cab xl pickup ------------ f-150
# sportage lx sport utility 4d ------------ cherokee ------------ f-150
# silverado 1500 hybrid ------------ 1500 crew cab big horn ------------ f-150
# miata ------------ cts sedan 4d ------------ f-150
# 1500 ------------ ierra 1500 ------------ f-150
# rogue sv awd gas suv auto ------------ taurus limited 4dr sedan ------------ f-150
# corolla ------------ f150 lariat fx4 4x4 ------------ f-150
# g6 ------------ AM General HMMWV ------------ f-150
# colorado ------------ 3500 big horn ------------ f-150
# macan s 67k msrp* premium package plus* gloss black window trim*roof rails in black* 20" rs spyder wheels* navigation* heated and ventilated seats*tinted windows ------------ cruze rs ------------ f-150
# x3 ------------ ranger supercrew xl pickup ------------ f-150
# pilot touring 8-passenger awd ------------ suburban ltz ------------ f-150
# charger r/t max ------------ TAB Dutchman ------------ f-150
# terrain ------------ 4runner sr5 sport utility ------------ f-150
# bronco ii ------------ corolla ------------ f-150
# camry ------------ wrangler unlimited ------------ f-150
# 7 series ------------ charger ------------ f-150
# model b ------------ Maserati GHIBLI ------------ f-150
# impreza wrx limited sedan ------------ tacoma access cab trd ------------ f-150
# ranger supercab xl pickup ------------ rx 330 awd ------------ f-150
# prius hybrid ------------ outback ------------ f-150
# 3 series 340i sedan 4d ------------ grand cherokee ------------ f-150
# Grand Caravan ------------ suburban 1500 lt ------------ f-150
# mkz awd ------------ silverado 2500hd ------------ f-150
# taurus sel ------------ mazda3 ------------ f-150
# renegade ------------ xc40 ------------ f-150
# matrix hatchback s fwd ------------ super duty f-350 srw ------------ f-150
# xf 20d premium sedan 4d ------------ 350z convertible ------------ f-150
# tacoma ------------ impala ------------ f-150
# q50 ------------ s2000 ------------ f-150
# scion fr-s ------------ is 250 awd ------------ f-150
# benz c250 ------------ lacrosse ------------ f-150
# corolla ------------ benz c250 ------------ f-150
# silverado 2500hd lt ------------ accord crosstour ------------ f-150
# grand cherokee ------------ mx-5 miata club ------------ f-150
# x3 sdrive30i sport utility ------------ sport svr ------------ f-150
# f550 xl ------------ 2500 ------------ f-150
# super duty f-250 ------------ rogue ------------ f-150
# volt ------------ 2500 ------------ f-150
# corolla le sedan 4d ------------ town & country ------------ f-150
# x5 ------------ corolla ------------ f-150
# tacoma ------------ freightliner cascadia evolution ------------ f-150
# tahoe ------------ explorer ------------ f-150
# soul ------------ rdx sh-awd technology pkg ------------ f-150
# super duty f-350 srw ------------ international 4400 ------------ f-150
# super duty f-350 srw ------------ international 4400 ------------ f-150
# transit cargo ------------ super duty f-350 drw ------------ f-150
# 300 ------------ tundra ------------ f-150
# accord ------------ avalon xls ------------ f-150
# es 350 ------------ 4runner ------------ f-150
# forte ------------ xj12 ------------ f-150
# 4runner ------------ durango ------------ f-150
# 1500 crew cab big horn ------------ cherokee ------------ f-150
# accord ex-l v6 ------------ 3i touring ------------ f-150
# vibe ------------ super duty f-550 drw ------------ f-150
# 4runner sr5 4x4 gas suv ------------ impala ------------ f-150
# camry xl ------------ f-150 ------------ f-150
# s-class ------------ mkz ------------ f-150
# silverado 1500 ls 4wd ------------ a4 2.0t premium plus ------------ f-150
# silverado 1500 lt 4x4 ------------ edge ------------ f-150
# qx60 luxe sport utility ------------ prowler ------------ f-150
# range evoque se ------------ pilot ------------ f-150
# cts ------------ tundra ------------ f-150
# f250 diesel ------------ IH Travelall ------------ f-150
# sonata ------------ e-class ------------ f-150
# dart ------------ focus ------------ f-150
# lifted silverado 3500 ------------ 1500 crew cab big horn ------------ f-150
# cars and suvs ------------ focus ------------ f-150
# benz c300 ------------ prius ------------ f-150
# cooper ------------ tacoma double cab trd ------------ f-150
# cruze limited 1lt ------------ mustang ------------ f-150
# 3 sport ------------ tacoma ------------ f-150
# mustang ------------ Isuzu NPR ------------ f-150
# tacoma ------------ f-150 ------------ f-150
# cx-7 ------------ camry ------------ f-150
# mkx reserve sport ------------ accord ------------ f-150
# traverse ------------ accord ex-l sedan 4d ------------ f-150
# rogue ------------ International 4300 ------------ f-150
# econoline commercial cutaway ------------ fusion ------------ f-150
# forte lx ------------ impala lt ------------ f-150
# 1500 ------------ ats luxury coupe 2d ------------ f-150
# cx-5 ------------ avenger ------------ f-150
# rav4 ------------ 2500 ------------ f-150
# c-class ------------ sonata ------------ f-150
# f150 regular cab xl pickup ------------ x1 xdrive28i ------------ f-150
# g35 ------------ isuzu npr hd ------------ f-150
# 7 series 750i xdrive sedan ------------ caliber ------------ f-150
# f-150 ------------ mdx sh-awd sport utility ------------ f-150
# outlander se sport ------------ g2500 ------------ f-150
# cr-v ------------ outback ------------ f-150
# focus ------------ silverado 1500 quad 4x4 ------------ f-150
# tahoe ------------ ranger supercrew xlt pickup ------------ f-150
# mx-5 miata grand touring ------------ charger ------------ f-150
# enclave avenir sport ------------ wrx sti ------------ f-150
# edge ------------ mkx select sport utility ------------ f-150
# tl ------------ liberty ------------ f-150
# f250 super duty xlt ------------ tiguan ------------ f-150
# cr-v ex ------------ legacy ------------ f-150
# f-150 lariat ------------ 4runner limited ------------ f-150
# equinox fwd 4dr lt w/ ------------ silverado 1500 ------------ f-150
# tacoma ------------ gti autobahn ------------ f-150
# 2500 ------------ wrangler unlimited rubicon ------------ f-150
# passport sport suv 4d ------------ enclave ------------ f-150
# journey sxt ------------ elantra ------------ f-150
# veloster ------------ pickup truck ------------ f-150
# explorer ------------ veloster value edition ------------ f-150
# silverado 1500 ------------ f550 ------------ f-150
# certified ------------ malibu ltz - sunroof - leather and heated seats - ------------ f-150
# prelude ------------ impala ------------ f-150
# f150 xlt ------------ benz c300 ------------ f-150
# impala ------------ sienna ------------ f-150
# xc90 ------------ benz c300 4matic ------------ f-150
# HUMMER H2 ------------ is 250 awd ------------ f-150
# mazda3 ------------ KW T300 ------------ f-150
# wrangler ------------ 550i ------------ f-150
# escape ------------ 1500 regular cab tradesman ------------ f-150
# escape ------------ wrangler sport ------------ f-150
# qx50 ------------ camaro lt ------------ f-150
# explorer ------------ 1500 classic regular cab ------------ f-150
# tundra crewmax sr5 pickup ------------ camaro ------------ f-150
# tundra 4wd ------------ fusion ------------ f-150
# f-150 ------------ cruze ------------ f-150
# ...
# trax ------------ mkx reserve sport ------------ f-150
# santa fe ------------ 200 series ------------ f-150
# 300 limited ------------ santa fe ------------ f-150
# grand caravan se ------------ Isuzu Rodeo ------------ f-150
# forester ------------ silverado 2500hd ------------ f-150
# mkz 4dr sdn awd ------------ silverado 1500 double ------------ f-150
# glk-class glk 350 ------------ allante ------------ f-150
# tacoma double cab ------------ x5 ------------ f-150
# cx-9 ------------ tacoma double cab ------------ f-150
# f59 18 ------------ focus ------------ f-150
# sentra sv cvt ------------ e-class ------------ f-150
# f-150 ------------ yukon slt sport utility 4d ------------ f-150
# venza wagon 4d ------------ benz e350 4matic ------------ f-150
# civic lx ------------ grand prix ------------ f-150
# expedition xlt sport ------------ xt4 sport ------------ f-150
# escape xlt ------------ durango ------------ f-150
# corolla ------------ elantra ------------ f-150
# mazda3 ------------ silverado 1500 crew ------------ f-150
# 3500 ------------ pathfinder ------------ f-150
# silverado 2500hd ------------ acadia ------------ f-150
# roadmaster wagon ------------ Maserati Ghibli ------------ f-150
# wrangler unlimited sahara ------------ 1500 classic slt ------------ f-150
# mustang mach 1 ------------ 2500 ------------ f-150
# legacy 2.5i limited ------------ 1500 ------------ f-150
# c-class ------------ accord sedan ------------ f-150
# sierra 1500 double cab sle ------------ f-150 xlt fx4crew cab ------------ f-150
# expedition ------------ sierra 1500 ------------ f-150
# journey ------------ wrx sti sedan 4d ------------ f-150
# journey ------------ wrx sti sedan 4d ------------ f-150
# soul base ------------ yukon xl ------------ f-150
# caravan ------------ romeo stelvio sport suv 4d ------------ f-150
# e-class ------------ elantra ------------ f-150
# silverado 1500 lt ------------ liberty ------------ f-150
# silverado ------------ outlander sport es ------------ f-150
# FREIGHTLINER M2 BUSINESS CLA ------------ flex ------------ f-150
# 4 series 430i xdrive gran ------------ f-150 ------------ f-150
# 2500 lone star crew cab ------------ f250 ------------ f-150
# expedition ------------ focus ------------ f-150
# tacoma ------------ ridgeline sport pickup 4d ------------ f-150
# sienna ------------ expedition ------------ f-150
# benz c250 ------------ cc4500 ------------ f-150
# q5 tdi premium plus sport ------------ prius ------------ f-150
# odyssey minivan ------------ xt4 sport suv 4d ------------ f-150
# soul + ------------ elantra se 4dr sedan ------------ f-150
# jetta ------------ qx56 ------------ f-150
# escalade 2011 ------------ equinox ------------ f-150
# mustang ------------ camaro lt ------------ f-150
# murano ------------ rogue sv sport utility 4d ------------ f-150
# murano ------------ rogue sv sport utility 4d ------------ f-150
# silverado 1500 ------------ highlander le sport ------------ f-150
# mustang gt ------------ sierra ------------ f-150
# vue ------------ lucerne ------------ f-150
# cts ------------ 2500 ------------ f-150
# malibu ls ------------ 135i ------------ f-150
# veloster ------------ accord sedan ------------ f-150
# escape se 4wd ------------ charger ------------ f-150
# ranger ------------ land cruiser ------------ f-150
# xterra ------------ grand cherokee ------------ f-150
# wrangler unlimited ------------ park avenue ------------ f-150
# yukon ------------ silverado 1500 crew ------------ f-150
# accord ------------ prius v hatchback ------------ f-150
# jetta ------------ s-10 ------------ f-150
# transit 250 ------------ elantra ------------ f-150
# optima ------------ fusion ------------ f-150
# silverado 1500 ld ------------ tahoe ------------ f-150
# 4runner trd off-road premium new bilstein-toytec lift*new 17"trd pro wheels*new 33" yokohama geolander goo3 m/t tires*tyger rock sliders*tyger roof basket*leather*nav*back up cam ------------ sierra denali ------------ f-150
# q5 ------------ liberty ------------ f-150
# tundra double cab sr ------------ optima sx limited just 27k ------------ f-150
# savana ------------ benz ml 350 4-matic ------------ f-150
# altima ------------ c-max hybrid ------------ f-150
# impreza wrx sti sedan 4d ------------ e-class e 550 ------------ f-150
# equinox awd ------------ e-class ------------ f-150
# tlx ------------ volt ------------ f-150
# 1500 quad cab slt pickup 4d ------------ f-350 super duty ------------ f-150
# 1500 quad cab express pickup ------------ 1500 quad cab slt pickup 4d ------------ f-150
# g6 ------------ encore ------------ f-150
# pathfinder ------------ compass ------------ f-150
# s5 premium plus convertible ------------ colorado ------------ f-150
# murano sv awd ------------ cooper s e countryman ------------ f-150
# f-350 ------------ volt premium ------------ f-150
# imapla limited lt ------------ f-150 ------------ f-150
# suburban ------------ silverado 3500hd ------------ f-150
# odyssey touring minivan ------------ tacoma access cab sr5 ------------ f-150
# acadia ------------ challenger ------------ f-150
# altima ------------ tundra sr5 ------------ f-150
# forester ------------ q8 premium sport utility 4d ------------ f-150
# explorer ------------ f-150 ------------ f-150
# silverado lt 1500 ------------ romeo giulia (952) ------------ f-150
# f-350 ------------ charger ------------ f-150
# crown victoria ------------ gla-class gla 45 ------------ f-150
# traverse ------------ gto ------------ f-150
# camry ------------ romeo giulia sedan 4d ------------ f-150
# focus zx4 s ------------ versa ------------ f-150
# genesis ------------ x5 ------------ f-150
# g g37x sedan 4d ------------ silverado 1500 double ------------ f-150
# x3 ------------ tacoma ------------ f-150
# Any ------------ accent ------------ f-150
# f-150 ------------ escape sel ------------ f-150
# frontier ------------ silverado ------------ f-150
# wrangler unlimited all new ------------ cruze limited 1lt ------------ f-150
# accord ex ------------ mustang ------------ f-150
# cooper s countryman ------------ rdx sport utility 4d ------------ f-150
# prius plug-in ------------ encore essence ------------ f-150
# tl ------------ 2018,2017,2016,2015 MODELS ------------ f-150
# sienna ------------ gla-class gla 250 ------------ f-150
# cherokee latitude ------------ f450 super duty crew cab & chassis ------------ f-150
# camry le ------------ tlx 3.5l v6 ------------ f-150
# super duty f-350 drw ------------ super duty f-350 srw laria ------------ f-150
# 1500 st ------------ camaro ------------ f-150
# 200 ------------ sonata sport sedan 4d ------------ f-150
# 1500 ------------ passat tdi ------------ f-150
# International LT ------------ 1500 ------------ f-150
# civic ------------ wrx premium sedan 4d ------------ f-150
# envoy ------------ renegade ------------ f-150
# mazda3 ------------ gs 450h ------------ f-150
# paceman cooper s all4 ------------ malibu ------------ f-150
# accord lx ------------ tacoma ------------ f-150
# ranger sport ------------ Scion FR-S Release Series 2.0 ------------ f-150
# pt cruiser gt 2dr ------------ 645ci convertible ------------ f-150
# sierra 2500 lbz duramax ------------ rio ------------ f-150
# sienna xle premium ------------ 2014 model S ------------ f-150
# edge ------------ rx330 awd ------------ f-150
# sentra ------------ lifted tacoma trd off 4x4 ------------ f-150
# 1500 ------------ elantra ------------ f-150
# xt5 ------------ 1500 outdoorsman ------------ f-150
# tundra ------------ corolla ------------ f-150
# spectra ------------ dart se ------------ f-150
# lifted sierra diesel duramax ------------ crosstour ex-l sport ------------ f-150
# TRD ------------ impreza 2.0i sport wagon ------------ f-150
# wrangler unlimited sahara ------------ 3 series 330i xdrive sedan ------------ f-150
# b-class electric ------------ chevolet TRAVERSE ------------ f-150
# sorento ------------ 4runner ------------ f-150
# f350 super duty lariat ------------ prius one hatchback 4d ------------ f-150
# Maserati Ghibli ------------ x3 ------------ f-150
# pickup 2500 ------------ charger se ------------ f-150
# 1500 ------------ corolla ------------ f-150
# hot rod ------------ silverado 3500 hd cre ------------ f-150
# 1988Ford Ranger XLT ------------ sierra 1500 double cab sle ------------ f-150
# plymouth prowler ------------ countryman ------------ f-150
# mustang v6 ------------ 1500 4x4 ------------ f-150
# sierra 2500hd ------------ wrangler ------------ f-150
# xf 20d premium sedan 4d ------------ prius ------------ f-150
# 5-series ------------ trailblazer ------------ f-150
# malibu ------------ crown victoria ------------ f-150
# a4 ------------ 300c ------------ f-150
# qx50 luxe sport utility ------------ sierra slt z71 ------------ f-150
# xc60 t5 drive-e premier ------------ x5 xdrive35i ------------ f-150
# e-class ------------ Scion xD ------------ f-150
# skylark custom ------------ xc90 t6 momentum awd 360 cam 3rd row seating leather ------------ f-150
# impala ------------ x3 ------------ f-150
# sentra sv ------------ suburban ltz ------------ f-150
# corolla ------------ benz c230 kompressor ------------ f-150
# prius v ------------ Hino 268 ------------ f-150
# 1500 tradesman 4x4 ------------ m-class ------------ f-150
# charger ------------ Kawasaki BN125-A ------------ f-150
# forester 2.5i premium ------------ silverado 1500 ------------ f-150
# sierra 1500 ------------ grand caravan ------------ f-150
# defender 90 ------------ explorer ------------ f-150
# silverado 1500 ------------ accord ------------ f-150
# outlander es sport ------------ 2017 ------------ f-150
# 3500 ------------ q3 sport premium plus ------------ f-150
# cts sedan ------------ 1500 regular cab tradesman ------------ f-150
# silverado 1500 ------------ f-150 xlt ------------ f-150
# 2500 ------------ hardtop 2 door cooper s ------------ f-150
# 4 series ------------ f-150 ------------ f-150
# prius hybrid ------------ tiburon coupe ------------ f-150
# silverado ------------ maxima ------------ f-150
# yukon denali xl ------------ cr-v ------------ f-150
# taurus ------------ 1500 crew cab big horn ------------ f-150
# f-150 ------------ grand cherokee overland ------------ f-150
# accord ------------ equinox lt ------------ f-150
# wrangler ------------ grand caravan se plus ------------ f-150
# cherokee ------------ 325i convertible ------------ f-150
# titan ------------ civic ------------ f-150
# camry xse sedan 4d ------------ prius c ------------ f-150
# corvette ------------ cts luxury ------------ f-150
# 4 series ------------ sienna xle fwd ------------ f-150
# 210 delray (bel air) ------------ x5 xdrive50i sport utility ------------ f-150
# E350 ------------ soul ------------ f-150
# m3 convertible 2d ------------ super duty f-550 drw ------------ f-150
# silverado 1500 ltz z71 ------------ mkt ------------ f-150
# ranger supercrew lariat ------------ edge st ------------ f-150
# f-150 ------------ silverado 1500 work tr ------------ f-150
# 1500 ------------ tacoma ------------ f-150
# enclave cxl ------------ altima ------------ f-150
# sienna awd ------------ Scion FR-S Coupe 2D ------------ f-150
# corolla ------------ sportage ------------ f-150
# ls 460 sedan 4d ------------ tundra access cab sr5 ------------ f-150
# WORKHORSE W42 ------------ altima 2.5 s ------------ f-150
# 200 lx ------------ srx ------------ f-150
# maverick ------------ c-class ------------ f-150
# sl 600 twin turbo hard top convertible pano 20s ------------ edge limited ------------ f-150
# edge ------------ accord lx ------------ f-150
# silverado 2500hd ------------ tacoma ------------ f-150
# tahoe ------------ x2 m35i m-sport package ------------ f-150
# s-class s 550 ------------ tacoma double cab ------------ f-150
# silverado 1500 crew cab ------------ 1500 crew cab tradesman ------------ f-150
# ELEMENT -- 4WD -- MOONROOF ------------ benz 380sl ------------ f-150
# comet ------------ expedition el ------------ f-150
# colorado crew cab work ------------ mkx ------------ f-150
# silverado 1500 double cab ------------ gs 350 sedan 4d ------------ f-150
# forester ------------ ranger fx4 off-road 4wd! ------------ f-150
# f250 ------------ sierra 3500hd ------------ f-150
# vue ------------ sonic ltz auto ------------ f-150
# mirage g4 es ------------ accord ------------ f-150
# camaro ------------ cruze ------------ f-150
# azera ------------ grand caravanj ------------ f-150
# 1500 quad cab tradesman ------------ deville ------------ f-150
# qx60 pure sport utility ------------ rav4 ------------ f-150
# altima 2.5 s ------------ sierra ------------ f-150
# accord ------------ 1500 bighorn 4x4 gas ------------ f-150
# spark ------------ xc60 t5 premier sport ------------ f-150
# camry xse ------------ 4runner limited sport ------------ f-150
# highlander ------------ fusion sel ------------ f-150
# rdx advance pkg sport ------------ cherokee ------------ f-150
# rogue ------------ camaro lt ------------ f-150
# yaris ia sedan 4d ------------ forte ------------ f-150
# 4runner ------------ odyssey ------------ f-150
# 6 series ------------ corvette z51 ------------ f-150
# 1500 quad cab tradesman ------------ camaro lt coupe 2d ------------ f-150
# q70 ------------ caravan/grand caravan ------------ f-150
# mr2 spyder ------------ soul ------------ f-150
# a3 2.0t quattro premium ------------ grand cherokee ------------ f-150
# f250 super duty ------------ f-150 ------------ f-150
# dart ------------ equinox premier ------------ f-150
# gs300 ------------ spark ------------ f-150
# outlander sel sport ------------ x5 ------------ f-150
# q50 3.0t luxe sedan 4d ------------ sierra diesel duramax 3500 ------------ f-150
# pathfinder sl awd ------------ Scion xB ------------ f-150
# 5500 ------------ civic ex-l ------------ f-150
# forte ------------ benz c32 amg ------------ f-150
# sierra 2500hd ------------ tacoma truck 4x4 ------------ f-150
# x5 ------------ expedition ------------ f-150
# renegade latitude ------------ escape ------------ f-150
# enclave leather sport ------------ Charger ------------ f-150
# scion iq ------------ x4 xdrive28i sport utility ------------ f-150
# silverado 3500hd 4x4 ------------ hse 4x4 s ------------ f-150
# sonata ------------ rampage ------------ f-150
# 1500 crew cab ------------ avalon ------------ f-150
# ats 2.0l turbo ------------ miata ------------ f-150
# camry ------------ grand cherokee ------------ f-150
# sport hse ------------ sierra 1500 ------------ f-150
# tacoma trd ------------ focus ------------ f-150
# enclave leather sport ------------ silverado 2500hd ------------ f-150
# explorer ------------ renegade ------------ f-150
# tacoma double cab pickup ------------ f-150 ------------ f-150
# 500 ------------ super duty f-250 srw ------------ f-150
# crosstour ex-l sport ------------ express cargo van ------------ f-150
# grand caravan ------------ crosstour ex-l sport ------------ f-150
# jimmy ------------ f350 dually diesel ------------ f-150
# civic ------------ t bucket ------------ f-150
# grand cherokee ------------ impala ------------ f-150
# fusion ------------ gx 470 4dr suv ------------ f-150
# s-class ------------ 6 ------------ f-150
# romeo stelvio sport suv 4d ------------ journey se suv ------------ f-150
# is 350 ------------ versa note sr sr, hatchback ------------ f-150
# silverado ------------ silverado ------------ f-150
# fusion ------------ armada platinum ------------ f-150
# 5 series ------------ cherokee ------------ f-150
# PROGRAMS as little as $500 DOWN! ------------ grand cherokee ------------ f-150
# f-450 crew cab dump truck 6 ------------ mustang ------------ f-150
# f250 superduty ------------ Janesville ------------ f-150
# a4 ------------ sierra 1500 limited double ------------ f-150
# jetta ------------ astro van ------------ f-150
# outlander sport le ------------ expedition limited ------------ f-150
# f-150 lariat crew cab 4x4 ------------ corvette ------------ f-150
# 1500 ------------ xt6 ------------ f-150
# 3 ------------ civic ex-t ------------ f-150
# santa fe awd ------------ escape se ------------ f-150
# mx-5 miata ------------ gla-class ------------ f-150
# edge ------------ traverse ------------ f-150
# bronco xlt 4x4 ------------ cr-v ------------ f-150
# altima 2.5 ------------ sportage lx sport utility 4d ------------ f-150
