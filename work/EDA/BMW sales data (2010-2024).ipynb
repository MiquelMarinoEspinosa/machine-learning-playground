# %%
import pandas as pd
#import matplotlib
import numpy as np
# %matplotlib inline
# only in a Jupyter notebook
import matplotlib.pyplot as plt

df = pd.read_csv('../datasets/BMW sales data (2010-2024).csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Model                 50000 non-null  object
#  1   Year                  50000 non-null  int64
#  2   Region                50000 non-null  object
#  3   Color                 50000 non-null  object
#  4   Fuel_Type             50000 non-null  object
#  5   Transmission          50000 non-null  object
#  6   Engine_Size_L         50000 non-null  float64
#  7   Mileage_KM            50000 non-null  int64
#  8   Price_USD             50000 non-null  int64
#  9   Sales_Volume          50000 non-null  int64
#  10  Sales_Classification  50000 non-null  object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 4.2+ MB

# %%
df = pd.read_csv('../datasets/BMW sales data (2010-2024).csv')
#df.set_index('Year', inplace=True)
#df[df.Year == '2010'].groupby(by='Model').Price_USD.mean().plot(kind='bar',legend=True, figsize=(20, 15))
plt.figure(figsize=(15, 5), dpi=80)
for model in np.sort(df.Model.unique()):
    plt.plot(df[df.Model == year].groupby(by='Model').Price_USD.mean())
plt.legend(np.sort(df.Year.unique()), loc=1)
plt.show()

# %%
df = pd.read_csv('../datasets/BMW sales data (2010-2024).csv')
#df[df.Year == 2010].groupby(by='Model').Price_USD.plot(by='Year', kind='line',legend=True, figsize=(20, 15))
#df.groupby(by='Model').describe()
df.set_index('Year', inplace=True)
#df.index
df[df.index == 2016].groupby(['Model']).head()
# Out:
#          Model         Region   Color Fuel_Type Transmission  Engine_Size_L  \
# Year
# 2016  5 Series           Asia     Red    Petrol       Manual            3.5
# 2016        X3  South America   White    Diesel    Automatic            1.7
# 2016        i8  North America    Blue    Hybrid       Manual            1.9
# 2016        M3         Africa   Black    Hybrid       Manual            1.5
# 2016        X6  South America  Silver    Hybrid    Automatic            4.9
# 2016        M3  South America    Grey  Electric    Automatic            3.0
# 2016        X1         Europe   Black    Petrol       Manual            2.1
# 2016  7 Series         Africa    Grey    Petrol    Automatic            2.1
# 2016        X5         Europe  Silver    Petrol    Automatic            4.7
# 2016        i3  North America   Black    Petrol       Manual            2.3
# 2016        X1         Africa    Grey    Petrol       Manual            4.1
# ...

# %%
df.groupby(by=['Year', 'Model']).Price_USD.describe()
# Out:
#                count          mean           std      min       25%      50%  \
# Year Model
# 2010 3 Series  317.0  75495.605678  26799.207570  30250.0  53872.00  76844.0
#      5 Series  299.0  73764.491639  26453.260261  30213.0  49991.50  74974.0
#      7 Series  279.0  76126.290323  26492.102143  30832.0  52796.50  76422.0
#      M3        292.0  75610.136986  24724.675298  30300.0  54571.75  74294.5
#      M5        310.0  73109.874194  25753.689904  30139.0  50950.50  72678.5
# ...              ...           ...           ...      ...       ...      ...
# 2024 X3        323.0  76452.529412  26866.972054  30054.0  52597.00  78872.0
#      X5        281.0  73870.366548  25672.565685  30447.0  51776.00  73424.0
#      X6        345.0  76078.495652  26618.460813  30096.0  51488.00  75784.0
#      i3        327.0  73823.232416  25357.871620  30067.0  51192.50  72388.0
#      i8        308.0  76449.084416  26220.213186  30072.0  55972.25  77015.5
#
# ...

# %%
cols = [col for col in df.columns if df[col].dtype == 'object']
df[cols].describe()
# Out:
#            Model Region  Color Fuel_Type Transmission Sales_Classification
# count      50000  50000  50000     50000        50000                50000
# unique        11      6      6         4            2                    2
# top     7 Series   Asia    Red    Hybrid       Manual                  Low
# freq        4666   8454   8463     12716        25154                34754

# %%
df['Model'].value_counts()
# Out:
# Model
# 7 Series    4666
# i3          4618
# i8          4606
# 3 Series    4595
# 5 Series    4592
# X1          4570
# X3          4497
# X5          4487
# M5          4478
# X6          4478
# M3          4413
# Name: count, dtype: int64

# %%
df['Model'].value_counts().plot.barh()
# Out:
# <Axes: ylabel='Model'>

# %%
df.head()
# Out:
#       Model  Year         Region  Color Fuel_Type Transmission  Engine_Size_L  \
# 0  5 Series  2016           Asia    Red    Petrol       Manual            3.5
# 1        i8  2013  North America    Red    Hybrid    Automatic            1.6
# 2  5 Series  2022  North America   Blue    Petrol    Automatic            4.5
# 3        X3  2024    Middle East   Blue    Petrol    Automatic            1.7
# 4  7 Series  2020  South America  Black    Diesel       Manual            2.1
#
#    Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# 0      151748      98740          8300                 High
# 1      121671      79219          3428                  Low
# 2       10991     113265          6994                  Low
# 3       27255      60971          4047                  Low
# 4      122131      49898          3080                  Low

# %%
df.tail()
# Out:
#           Model  Year         Region   Color Fuel_Type Transmission  \
# 49995        i3  2014           Asia     Red    Hybrid       Manual
# 49996        i3  2023    Middle East  Silver  Electric       Manual
# 49997  5 Series  2010    Middle East     Red    Petrol    Automatic
# 49998        i3  2020           Asia   White  Electric    Automatic
# 49999        X1  2020  North America    Blue    Diesel       Manual
#
#        Engine_Size_L  Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# 49995            4.6      151030      42932          8182                 High
# 49996            4.2      147396      48714          9816                 High
# 49997            4.5      174939      46126          8280                 High
# 49998            3.8        3379      58566          9486                 High
# 49999            3.3      171003      77492          1764                  Low

# %%
df.loc[np.argmax(df.Price_USD)]
# Out:
# Model                            i8
# Year                           2010
# Region                  Middle East
# Color                        Silver
# Fuel_Type                  Electric
# Transmission                 Manual
# Engine_Size_L                   4.2
# Mileage_KM                   115320
# Price_USD                    119998
# Sales_Volume                   5842
# Sales_Classification            Low
# Name: 26071, dtype: object

# %%
df.hist(by='Year', column='Price_USD', bins=50, figsize=(20, 15), legend=True)
plt.show()

# %%
df.hist(by='Year', column='Sales_Volume', bins=50, figsize=(20, 15), legend=True)
plt.show()

# %%
df.hist(bins=50, figsize=(20, 15))
plt.show()

# %%
df.describe()
# Out:
#                Year  Engine_Size_L     Mileage_KM      Price_USD  Sales_Volume
# count  50000.000000   50000.000000   50000.000000   50000.000000  50000.000000
# mean    2017.015700       3.247180  100307.203140   75034.600900   5067.514680
# std        4.324459       1.009078   57941.509344   25998.248882   2856.767125
# min     2010.000000       1.500000       3.000000   30000.000000    100.000000
# 25%     2013.000000       2.400000   50178.000000   52434.750000   2588.000000
# 50%     2017.000000       3.200000  100388.500000   75011.500000   5087.000000
# 75%     2021.000000       4.100000  150630.250000   97628.250000   7537.250000
# max     2024.000000       5.000000  199996.000000  119998.000000   9999.000000
